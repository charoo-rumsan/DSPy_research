# %% [markdown]
# <a href="https://colab.research.google.com/github/charoo-rumsan/DSPy_research/blob/main/embedding_sentence_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# Specify the path to your CSV file here
file_path = "/content/first_100_rows (1) - first_100_rows (1).csv.csv"

uploaded_filename = None

# Check if the file exists locally
if os.path.exists(file_path):
    uploaded_filename = file_path
    print(f"Local file '{uploaded_filename}' is ready to be used.")
else:
    print(f"Error: File not found at '{file_path}'. Please ensure the file exists at this path.")
# Out:
# Local file '/content/first_100_rows (1) - first_100_rows (1).csv.csv' is ready to be used.

# %%
import csv
import os
from pathlib import Path
import polars as pl

class HeaderExtractor:
    def __init__(self):
        self.supported_formats = ['.csv', '.tsv', '.txt']

    def extract_headers_from_file(self, file_path: str):
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"File not found: {file_path}")

        file_ext = Path(file_path).suffix.lower()
        if file_ext not in self.supported_formats:
            raise ValueError(f"Unsupported file format: {file_ext}")

        headers = self._extract_headers(file_path)
        print(f"✅ Extracted {len(headers)} headers from file.")

        return headers

    def _extract_headers(self, file_path: str):
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            sample = f.read(1024)
            f.seek(0)
            delimiter = csv.Sniffer().sniff(sample).delimiter
        df = pl.read_csv(file_path, separator=delimiter, n_rows=0)
        return df.columns

# %%
import json

# Instantiate the HeaderExtractor
extractor = HeaderExtractor()

# Assuming 'uploaded_filename' holds the path to your CSV file from earlier steps
if 'uploaded_filename' in locals() and uploaded_filename:
    # Extract headers using the new class
    extracted_headers = extractor.extract_headers_from_file(uploaded_filename)

    print("\nHeaders extracted using HeaderExtractor:")
    print(extracted_headers)

    # Save to JSON file
    output_filename = 'extracted_headers_using_class.json'
    with open(output_filename, 'w') as f:
        json.dump(extracted_headers, f, indent=4)
    print(f"\nHeaders also saved to {output_filename}")

else:
    print("No CSV file was uploaded. Please upload a file first.")
# Out:
# ✅ Extracted 353 headers from file.
#
# Headers extracted using HeaderExtractor:
# ['', 'start', 'end', 'today', 'username', 'simserial', 'subscriberid', 'deviceid', 'phonenumber', 'General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)', 'General Questions/Municipality and Ward Details/Ward Number (वडा नं .)', 'General Questions/Municipality and Ward Details/Ward Number (वडा नं )', 'General Questions/Name of the Tole (सर्वेक्षण भैरहेको स्थानको नाम)', 'General Questions/House No. (घर नं)', 'GPS Coordinates', 'General Questions/_GPS Coordinates_latitude', 'General Questions/_GPS Coordinates_longitude', 'General Questions/_GPS Coordinates_altitude', 'General Questions/_GPS Coordinates_precision', 'General Questions/Do I have your consent to conduct this survey? (के यो सर्भे गर्नमा तपाइको सहमति छ?)', 'Basic Details of House Owner/Information on house owner/Name of the house owner (घरमुलीको नाम)', 'Basic Details of House Owner/Information on house owner/Age of the house owner (घरमुलीको उमेर)', 'Basic Details of House Owner/Information on house owner/Marital status of house owner (घरमुलीको वैवाहिक स्थिति)', 'Basic Details of House Owner/Information on house owner/Gender of house owner (घरमुलीको बिवरण)', 'Basic Details of House Owner/Information on house owner/Is the house owner differently abled? के घर मालिक फरक रूपमा सक्षम हुनहुन्छ?', 'Basic Details of House Owner/Language and Ethnicity/Mother Tongue (मातृभाषा)', 'Basic Details of House Owner/Language and Ethnicity/If other, specify here. (यदि अन्य मातृभाषा भएमा, यहाँ उल्लेख गर्नुहोस)', 'Basic Details of House Owner/Language and Ethnicity/What is the ethnicity of the family? (परिवार कुन जातिमा पर्नुहुन्छ?)', 'Basic Details of House Owner/Language and Ethnicity/If other, please specify (यदि अन्य भए, यहाँ उल्लेख गर्नुहोस्)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female  ...
#
# Headers also saved to extracted_headers_using_class.json

# %% [markdown]
# Approach 1: Embedding + Clustering + Auto-Normalization
#
# This version:
#
# Clusters similar headers (unsupervised)
#
# Generates a representative label for each cluster (automatic)
#
# Converts the label into clean snake_case
#
# No predefined labels needed.
#
# Uses:
#
# Sentence Transformers for embeddings
#
# KMeans for clustering
#
# A normalization function to auto-generate labels

# %%
pip install sentence-transformers scikit-learn numpy

# %% [markdown]
# Step 1 — Import + Load Model

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import numpy as np
import re

model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# %% [markdown]
# Step 2 — Convert Headers Into Embeddings

# %%
headers = extracted_headers   # from your HeaderExtractor class
embeddings = model.encode(headers)
embeddings = np.array(embeddings)

# %% [markdown]
# Step 3 — Determine Number of Clusters Automatically

# %%
import math

num_headers = len(headers)
k = max(2, int(math.sqrt(num_headers)))   # sqrt rule

print("Clustering into:", k, "clusters")
# Out:
# Clustering into: 18 clusters

# %% [markdown]
# Step 4 — Run KMeans Clustering

# %%
kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(embeddings)

# %% [markdown]
# Step 5 — Auto-Generate a Standard Label for Each Cluster
# Rule:
#
# Pick the most common meaningful words in the cluster
#
# Normalize to snake_case
#
# Remove Nepali text, numbers, symbols, etc.

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^\w\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def extract_keywords(text):
    # simple keyword extractor (can be upgraded)
    words = clean_text(text).split()
    words = [w for w in words if len(w) > 2]  # remove very short words
    return words

def to_snake_case(words):
    return "_".join(words)

# %%
from collections import Counter

cluster_labels = {}

for cluster_id in range(k):
    cluster_headers = [headers[i] for i in range(num_headers) if clusters[i] == cluster_id]

    # gather keywords across all headers in cluster
    all_words = []
    for h in cluster_headers:
        all_words.extend(extract_keywords(h))

    if not all_words:
        label = f"cluster_{cluster_id}"
    else:
        # pick top 2–3 frequent keywords
        common = [w for w, _ in Counter(all_words).most_common(3)]
        label = to_snake_case(common)

    cluster_labels[cluster_id] = label

# %% [markdown]
# Step 6 — Generate Final Mapping (Header → Auto Label)

# %%
auto_labeled = {}

for i, h in enumerate(headers):
    cluster_id = clusters[i]
    auto_labeled[h] = cluster_labels[cluster_id]

auto_labeled
# Out:
# {'': 'meter_घरब_katha',
#  'start': 'meter_घरब_katha',
#  'end': 'meter_घरब_katha',
#  'today': 'meter_घरब_katha',
#  'username': 'meter_घरब_katha',
#  'simserial': 'meter_घरब_katha',
#  'subscriberid': 'meter_घरब_katha',
#  'deviceid': 'meter_घरब_katha',
#  'phonenumber': 'meter_घरब_katha',
#  'General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)': 'the_house_details',
#  'General Questions/Municipality and Ward Details/Ward Number (वडा नं .)': 'the_house_details',
#  'General Questions/Municipality and Ward Details/Ward Number (वडा नं )': 'the_house_details',
#  'General Questions/Name of the Tole (सर्वेक्षण भैरहेको स्थानको नाम)': 'meter_घरब_katha',
#  'General Questions/House No. (घर नं)': 'the_house_details',
#  'GPS Coordinates': 'resources_distance_general',
#  'General Questions/_GPS Coordinates_latitude': 'resources_distance_general',
#  'General Questions/_GPS Coordinates_longitude': 'resources_distance_general',
#  'General Questions/_GPS Coordinates_altitude': 'resources_distance_general',
#  'General Questions/_GPS Coordinates_precision': 'resources_distance_general',
#  'General Questions/Do I have your consent to conduct this survey? (के यो सर्भे गर्नमा तपाइको सहमति छ?)': 'resources_access_various',
#  'Basic Details of House Owner/Information on house owner/Name of the house owner (घरमुलीको नाम)': 'house_owner_basic',
#  'Basic Details of House Owner/Information on house owner/Age of the house owner (घरमुलीको उमेर)': 'house_owner_basic',
#  'Basic Details of House Owner/Information on house owner/Marital status of house owner (घरमुलीको वैवाहिक स्थिति)': 'house_owner_basic',
#  'Basic Details of House Owner/Information on house owner/Gender of house owner (घरमुलीको बिवरण)': 'house_owner_basic',
#  'Basic Details of House Owner/Information on house owner/Is the house owner differently abled? के घर मालिक फरक रूपमा सक्षम हुनहुन्छ?': 'house_owner_basic',
#  'Basic Details of House Owner/Language and Ethnicity/Mother Tongue (मातृभाषा)': 'house_owner_basic',
#  'Basic Details of House Owner/Language and Ethnicity/If other, specify here. (यदि अन्य मातृभाषा भएमा, यहाँ उल्लेख गर्नुहोस)': 'house_owner_basic',
#  'Basic Details of House Owner/Language and Ethnicity/What is the ethnicity of the family? (परिवार कुन जातिमा पर्नुहुन्छ?)': 'house_owner_basic',
#  'Basic Details of House Owner/Language and Ethnicity/If other, please specify (यदि अन्य भए, यहाँ उल्लेख गर्नुहोस्)': 'house_owner_basic',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला सद': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/total_female': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Female is ${total_female}': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने पुरुष  सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/total_male': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Male is ${total_male}': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या )': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या) )': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/total_other': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Others is ${total_other}': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/total_members': 'members_age_group',
#  'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of family members is ${total_members}': 'members_age_group',
#  'Family Members Details/Identity Revealing Document/Do the house members have identity revealing documents? (के तपाइँ र तपाईको घरका सदस्यहरुसंग आफ्नो परिचय खुल्ने कागजात छ?)': 'the_family_members',
#  'Family Members Details/Identity Revealing Document/If few members do not have, specify the number. (यदि कसैको छैन भने, कति जनाको छैन यहाँ उल्लेख गर्नुहोस)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Pregnant and Lactating (गर्भवती तथा स्तनपान गराउने)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Widowed (विदुवा/विदुर)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Chronically ill (दिर्घकालिन रोग भएको)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Single Woman (एकल महिला)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/None of the above (माथिका कुनै पनि छैन)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, specify the number. (यदि गर्भवती र स्तनपान गराउने हुनुहुन्छ भने, कति जना हुनुहुन्छ?': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, are they differently abled? (यदि गर्भवती तथा स्तनपान गराउने भए, उहाहरु अपाङ्गता भएको वा फरक रुपमा सक्षम हुनुहुन्छ?)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If yes, please write down the number of people with disability pregnant and lactating woman (यदि हुनुन्छ भने, अपाङ्गता भएको वा फरक रुपमा सक्षम कति जना हुनुन्छ?': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Female (महिला)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Male (पुरुष)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Other (अन्य)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Widowed/How many members in the family members are widowed? (घरका कतिजना सदस्य विधवा/विदुर हुनुहुन्छ?)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Single woman/If single woman, how many members in the family are single woman? (यदि एकल महिला भएमा, कतिजना सदस्य एकल महिलामा पर्नुहुन्छ?)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, how many members in the family are people with disability? (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, घरमा कतिजना फरक रुपमा सक्षम हुनुहुन्छ?)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Physical disabilities (शारीरिक असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Visual disabilities (दृष्टि असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing disabilities (श्रवण असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing-Visual disabilities (श्रवण-दृश्य असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Speaking disabilities (बोल्ने असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Mental disabilities (मानसिक असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Intellectual disabilities (बौद्दिक  असक्षमता)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Multiple disabilities (धेरै असक्षमताहरु)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/Do the people with disability family member have identity revealing document provided by municipality? (के शारिरिक तथा मानसिक अपांगता भएको परिचय पत्र पालिका बाट प्राप्त गर्नुभएको छ?)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Red Card (रातो कार्ड)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Blue Card (निलो कार्ड)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Yellow Card (पहेलो कार्ड)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/White Card (सेतो कार्ड)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)': 'the_family_members',
#  'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, how many members in the family are chronically ill? (यदि दिर्घकालिन रोग भएमा, घरका कतिजना सदस्यहरुलाइ दिर्घकालिन रोग छ?)': 'the_family_members',
#  'Family Members Details/Education Status/Literacy/Total literate female members in the house ( घरमा कुल साक्षर महिला सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Literacy/Total literate male members in the house ( घरमा कुल साक्षर पुरुष सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Literacy/Total literate other gender members in the house ( घरमा कुल साक्षर महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Literacy/total_literate': 'members_education_family',
#  'Family Members Details/Education Status/Literacy/Total literate members of age between (15-60) years in the house (घरमा (१५-६०) वर्ष उमेर समुहका कुल साक्षर सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Total Number of Literate Family Members is ${total_literate}': 'members_education_family',
#  'Family Members Details/Education Status/total_illiterate': 'members_education_family',
#  'Family Members Details/Education Status/Total Number of Illiterate Family Members is ${total_illiterate}': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members who are not eligible for schooling  (परिवारका कुल सदस्यहरू जो पढ्न योग्य नभएका)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members with other/non-formal education (अन्य/अनौपचारिक शिक्षा लिएका परिवारका कुल सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members whose education level is not known ( कुल परिवारका सदस्य जसको शिक्षा स्तर थाहा छैन)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at primary level of schooling (कक्षा ५ सम्म) विद्यालयको प्राथमिक तहमा (पढ्ने/पढेका  कुल परिवारका सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at Lower Secondary level of schooling (विद्यालयको निम्न माध्यमिक तहमा  (कक्षा ८ सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at Secondary level of schooling (विद्यालयको  माध्यमिक तहमा ((कक्षा ९ वा १० सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at SLC or Equivalent level of schooling (SLC वा सो सरह स्तरमा पढ्ने/पढेका परिवारका कुल सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at Intermediate or Equivalent level of schooling (+२ पढ्ने/पढेका परिवारका कुल सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at Bachelor or Equivalent level of schooling (ब्याचलर वा सो सरह पढेका/पढ्ने परिवारका कुल सदस्यहरू)': 'members_education_family',
#  'Family Members Details/Education Status/Education Level/Total family members at Masters / Ph.D level of education (मास्टर्स/पी.एच.डी पढ्ने/पढेका परिवारका कुल सदस्यहरू)': 'members_education_family',
#  'Other Family Members Details/Are there any other families living in the same house? (तपाईको घरमा अन्य कुनै परिवार बस्नुहुन्छ?)': 'the_family_members',
#  'Other Family Members Details/If yes, how many female members are there? (यदि बस्नुहुन्छ भने, महिला सदस्य कतिजना हुनुहुन्छ?)': 'members_age_group',
#  'Other Family Members Details/How many male members are there? (यदि बस्नुहुन्छ भने, पुरुष सदस्य कतिजना हुनुहुन्छ?)': 'members_age_group',
#  'Other Family Members Details/How many members of other gender are there ? (यदि बस्नुहुन्छ भने, अन्य महिला वा पुरुष भनि पहिचान नगर्ने सदस्य कतिजना हुनुहुन्छ?)': 'members_age_group',
#  'Economic Condition of the House Owner Family/Major Occupation/What is the primary occupation of your family? (तपाईको घरको प्रमुख पेशा कुन हो?)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Major Occupation/If other, please specify (यदि अन्य मुख्य पेशा भए, यहाँ उल्लेख गर्नुहोस्)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Agriculture and Livestock (कृषि तथा पशुपालन)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/On-farm Daily Wage Worker (कृषि क्षेत्रमा दैनिक ज्याला मजदुर)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Off-farm Daily Wage Worker (गैर कृषि क्षेत्रमा दैनिक ज्याला मजदुर)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Business (व्यापार तथा व्यवसाय)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Government Service (सरकारी सेवा)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Private Job (निजी सेवा)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Foreign Employment/Remittance (वैदेशिक रोजगार)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Other (अन्य)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/No supporting occupation (कुनै सहायक पेशा छैन)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Supporting Occupation/If other, please specify (यदि अन्य सहायक पेशा भएमा, यहाँ उल्लेख गर्नुहोस)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Supporting Occupation/Number of unemployed members in the household (घरमा कतिजना वेरोजगार हुनुहुन्छ?)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Do you or your family members own land? (के तपाइँ र तपाइको परिवारको नाममा जग्गा-जमिन छ?)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/How much land do you or your family hold? (तपाइँ र तपाईको परिवारको जग्गा कति छ?)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other type, please specify the type of land (यदि अन्य भएमा, यहाँ उल्लेख गर्नुहोस)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Forested Area (वन क्षेत्र)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Open Space (खुल्ला स्थान)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Commercial Purpose (व्यापारिक क्षेत्र)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Other (अन्य)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other land type, please specify the type of land (यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Do the female members of the house own the land? (घरको महिला सदस्यको नाममा जग्गा-जमिन छ?)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Total land held by female of the house (घरको महिला सदस्यको नाममा भएको जग्गा कति छ?)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type that helds by female, please specify the type of land (महिला सदस्यले यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Forested Area (वन क्षेत्र)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Open Space (खुल्ला स्थान)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Commercial Purpose (व्यापारिक क्षेत्र)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Other (अन्य)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type, specify here. (यदि अन्य भू-उपयोग भएमा, यहाँ उल्लेख गर्नुहोस)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Income and Expenditure/Annual income of the family (वार्षिक आम्दानी)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Income and Expenditure/Monthly Expenditure of the house  (घरको मासिक खर्च)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Income and Expenditure/Yearly saving of the house  (घरको वार्षिक बचत)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Saving, Credit and Loan/Have you taken loan from the financial institutions? (के तपाइले कुनै वित्तीय संस्था बाट ऋण लिनुभएको छ?)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Saving, Credit and Loan/Covered by subsidized loan targeted for women/marginalized group (घरको  महिला/सीमान्तकृत समूहका लागि लक्षित सहुलियतपूर्ण ऋण पाएको छ?)': 'land_holding_the',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Is any family member receiving reservations, allowances and special privilege systems? (के तपाइको घरको कुनै सदस्यले कुनै आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen (ज्येष्ठ नागरिक)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Dalit (ज्येष्ठ नागरिक दलित)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Single Women (ज्येष्ठ नागरिक एकल महिला)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Widowed (विधवा/ एकल महिला)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Dalit Child Allowance (दलित बाल बालिका)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Pension (पेन्सन)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Others (अन्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If other type of privilege system, please specify (यदि अन्य किसिमको सुविधाहरु भएमा, यहाँ उल्लेख गर्नुहोस)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen allowance (वृद्द भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen dalit allowance (दलित वृद्द भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen single woman allowance (महिला वृद्द भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  widowed allowance (विधवा भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  allowance for differently abled (अपाङ्गता भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  allowance for dalit child (दलित बाल-बालिका  भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving pension (पेन्सन पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving other type of allowance (अन्य किसिमका भत्ता पाउनुहुने घरका सदस्य)': 'privilege_family_reservations',
#  'Economic Condition of the House Owner Family/Insurance Details/Have you or your family member taken any type of insurance? (के तपाइ तथा तपाँईको परिवारको कुनै सदस्यहरूले विमा गर्नुभएको छ?)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Life Insurance (जीवन विमा)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Animal Insurance (पशु विमा)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Crop Insurance (बाली विमा)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Health Insurance (स्वास्थ्य विमा)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Other (अन्य)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Insurance Details/If other type of insurance, please specify (यदि अन्य विमा भएमा, यहाँ उल्लेख गर्नुहोस)': 'insurance_family_the',
#  'Economic Condition of the House Owner Family/Occupational and Livelihood/Do you or your family fall in the Occupational and livelihood groups mentioned below? ( तल उल्लेख  पेशागत र जीविकोपार्जन समूहमा तपाइँ र तपाइको परिवार पर्नुहुन्छ?)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Occupational and Livelihood/If other occupational and livelihood groups, please specify (यदि अन्य पेशागत र जीविकोपार्जन समुह भएमा, यहाँ उल्लेख गर्नुहोस)': 'the_family_occupation',
#  'Economic Condition of the House Owner Family/Communication/Do you have communication device at your house? (के तपाइँको घरमा संचार साधन उपलब्ध छ?)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Radio (रेडियो)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/TV (टेलिभिजन)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Mobile Phone (मोबाइल फोन)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Telephone (टेलिफोन)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Internet (इन्टरनेट)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Computer (कम्प्यूटर)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Other (अन्य)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/Specify other type of communication devices available at your house. (यदि अन्य संचार  साधन भएमा, यहाँ उल्लेख गर्नुहोस)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If No, what is the medium of communication in the house? (यदि छैन भने,  संचारको अन्य माध्यमहरु के प्रयोग/उपलब्ध हुन्छ?)/Community Library (सामुदायिक पुस्तकालय)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If No, what is the medium of communication in the house? (यदि छैन भने,  संचारको अन्य माध्यमहरु के प्रयोग/उपलब्ध हुन्छ?)/Community Centre (सामुदायिक केन्द्र)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If No, what is the medium of communication in the house? (यदि छैन भने,  संचारको अन्य माध्यमहरु के प्रयोग/उपलब्ध हुन्छ?)/Other Medium of Communication (अन्य कुनै माध्यम)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If other medium, please specify here. (यदि अन्य माध्यम उपलब्ध भएमा, यहाँ उल्लेख गर्नुहोस)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/Do the women of the house have access to the communication devices? (घरका  महिला सदस्यको  संचार माध्यमको पहुँच छ?)': 'communication_house_the',
#  'Economic Condition of the House Owner Family/Communication/If no, what is the medium of communication used by the house? (यदि छैन भने,  संचारको अन्य माध्यमहरु के प्रयोग/उपलब्ध हुन्छ?)': 'communication_house_the',
# ...
#  'Access to Various Resources/Early Warning System/Do you understand the early warning information disseminated? (प्राप्त भएको  पुर्वसुचना बुझ्नुहुन्छ?)': 'early_warning_information',
#  'Access to Various Resources/Safe Shelter/Do you have access to safe shelter? (के तपाइको सुरक्षित आवासमा पहुँच छ?)': 'resources_access_various',
#  'Access to Various Resources/Safe Shelter/If yes, how far is safe shelter from your house? (यदि छ भने, सुरक्षित आवास तपाइको घरबाट कति टाढा छ?)': 'resources_access_various',
#  'Access to Various Resources/Safe Shelter/Please select the unit of distance measurement. (कृपया दूरी मापनको इकाइ चयन गर्नुहोस्।)': 'resources_distance_general',
#  'Access to Various Resources/Access to other resources/Access to clean drinking water during flood (बाढीको समयमा खानेपानीको सुविधा)': 'resources_access_various',
#  'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Forest (वन)': 'resources_access_various',
#  'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Water Resources (जलस्रोत)': 'resources_access_various',
#  'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Other natural resources (अन्य प्राकृतिक स्रोत)': 'resources_access_various',
#  'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Do not have access (कुनै पनि छैन)': 'resources_access_various',
#  'Access to Various Resources/Access to other resources/If other natural resources, please specify (यदि अन्य प्राकृतिक स्रोत भए, यहाँ उल्लेख गर्नुहोस)': 'resources_access_various',
#  'Details on the House/Structure Built and Permit/Age of the house (In years) (घर निर्माण भएको कति वर्ष भयो?)': 'the_house_details',
#  'Details on the House/Structure Built and Permit/Number of storey of the house (घरको तल्ला)': 'the_house_details',
#  'Details on the House/Structure Built and Permit/Is the building designed following building code? (के तपाइले घर बनाउदा भवन निर्माण संहिता पालना गरेर निर्माण गर्नुभएको हो?)': 'the_house_details',
#  'Details on the House/Structure Built and Permit/Have you received a building permit from the municipality? ( नगरपालिकाबाट निर्माण स्वीकृति लिनुभएको छ?)': 'the_house_details',
#  'Details on the House/Construction Materials/Type of foundation of the building (तल उल्लेख मध्ये तपाईको घरको जगको निर्माण सामाग्री के-के हुन्)': 'the_house_details',
#  'Details on the House/Construction Materials/If other type of foundation materials, please specify. (यदि अन्य प्रकारको निर्माण सामग्री भएमा, यहाँ उल्लेख गर्नुहोस)': 'the_house_details',
#  'Details on the House/Construction Materials/Please mention the building type of your house (तपाइको घर तल उल्लेख मध्ये कुन किसिमको हो?)': 'the_house_details',
#  'Details on the House/Construction Materials/If other type of building type, please specify. (यदि अन्य प्रकारको भवन भएमा, यहाँ उल्लेख गर्नुहोस)': 'the_house_details',
#  'Details on the House/Construction Materials/What materials are used for the construction of Wall of your house? (तपाइको घरको भित्ता के ले बनेको छ?)': 'the_house_details',
#  'Details on the House/Construction Materials/If other wall type, please specify (यदि अन्य सामग्रीले बनेको भएमा, यहाँ उल्लेख गर्नुहोस)': 'the_house_details',
#  'Details on the House/Construction Materials/What materials are used for the construction of Roof of your house? (तपाइको घरको छाना केले निर्माण गरिएको छ?)': 'the_house_details',
#  'Details on the House/Construction Materials/If other materials of roof, please specify. (यदि अन्य निर्माण सामग्रीले छाना बनेको भएमा, यहाँ उल्लेख गर्नुहोस)': 'the_house_details',
#  'Details on the House/Construction Materials/Is the roof easily accessible in case of any emergency? (के तपाइको घरको छतमा सजिलै जान र बस्न मिल्छ?)': 'the_house_details',
#  'Details on the House/Current Condition/What is the current condition of your house? (तपाइको घरको अहिलेको अवस्था कस्तो छ?)': 'the_house_details',
#  'Details on the House/Current Condition/How is the ground surface of the area in which your house has been built? (तपाईको घर निर्माण भएको जमिनको सतह कस्तो छ?)': 'the_house_details',
#  'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Raised Plinth and above flood level (उठाएको प्लिन्थ-बाढीको सतह भन्दा माथि)': 'the_house_details',
#  'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Strong wall (मजबुत पर्खाल)': 'the_house_details',
#  'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Proper drainage (उचित ढल/जल निकासी)': 'the_house_details',
#  'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/None of the above (माथिको कुनै पनि होइन)': 'the_house_details',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years, how many times have you experienced flooding events? (विगत ३० वर्षमा तपाइले कति पटक बाढीका घटनाहरुको अनुभव गर्नुभएको छ?)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past flooding events, what is the maximum depth of flood occurrence surrounding the household? विगतको बाढी घटनामा, घर वरिपरि बाढीको अधिकतम गहिराई कति थियो ?': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Select the unit of flood depth measurement. (बाढीको गहिराई नाप्ने इकाइ चयन गर्नुहोस्।)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Death of  household members (परिवारको सदस्यको मृत्यु भएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Missing household members (परिवारको सदस्य हराएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Injured household members (परिवारको सदस्य घाइते हुनुभएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/People displaced (विस्थापित)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to house (घरमा क्षति भएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Land affected (जमिन क्षति भएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Livestock affected (पशु क्षति भएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Farmland affected (खेति जमिनमा क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to stored food stock (भण्डारण गरिएको खाद्यान्न क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Non-Structural Damage (गैर-संरचनात्मक क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Loss of other livelihood options ( such as loss of job, business, other than agriculture)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/No any damage (कुनै पनि क्षति नभएको)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Number of people death (मृत्यु हुनेको संख्या)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Number of missing family members (हराएका परिवारको सदस्यको संख्या)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Number of injured family members (घाइतेको संख्या)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Number of people displaced (विस्थापित संख्या)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Total area of farmland affected (कुल खेति जमिन क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Unit of measurement of affected farmland area (प्रभावित खेति जमिन क्षेत्रको मापनको इकाइ)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Estimated agricultural loss (कुल कृषि क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Type of damage to the house (घरको क्षतिको प्रकार)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Total livestock loss (कुल पशु क्षतिको संख्या)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Estimated livestock loss NPR (कुल पशु क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Total loss of stored food KG (भण्डारण गरिएको खाद्यान्न क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/Total Estimated loss NPR (कुल अनुमानित क्षति)': 'and_loss_damage',
#  'Hazard and Disaster/Historical Damage and Loss/If loss of other livelihood options, please specify. अन्य जीविकोपार्जनका विकल्पहरू गुमाएमा, कृपया यहाँ उल्लेख गर्नुहोस्।': 'and_loss_damage',
#  'Hazard and Disaster/Knowledge and Training in Disaster/Have any family members received training on disaster? (के तपाइँ वा तपाईको परिवारको सदस्यले विपद सम्बन्धी तालिम लिनुभएको छ?)': 'disaster_and_training',
#  'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/First Aid (प्राथमिक उपचार)': 'disaster_and_training',
#  'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Search and rescue (खोज तथा उद्दार)': 'disaster_and_training',
#  'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Simulation and drill exercise (सिमुलेशन र ड्रिल)': 'disaster_and_training',
#  'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Other Disaster related training (विपद सम्बन्धी अन्य तालिम)': 'disaster_and_training',
#  'Hazard and Disaster/Knowledge and Training in Disaster/If other disaster related trainings received, please specify what type of trainings. (यदि विपद सम्बन्धी अन्य तालिम भएमा, यहाँ उल्लेख गर्नुहोस)': 'disaster_and_training',
#  'Hazard and Disaster/Aftermath of Past Disaster/Access to social assistance in the aftermath of past disaster (विगतको प्रकोप पछि सामाजिक सहायता प्राप्त भएको थियो?)': 'and_loss_damage',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/DRRM committee of ward/municipality (पालिका वा वडाको विपद सम्बन्धी समितिमा)': 'community_groups_are',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Women group (महिला समुह)': 'community_groups_are',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Youth group (युवा समुह)': 'community_groups_are',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Child group (बाल समुह)': 'community_groups_are',
#  "Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Single women's group (एकल महिला समुह)": 'community_groups_are',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Scout/Red cross (स्काउट/ रेड क्रस)': 'community_groups_are',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Other (अन्य)': 'community_groups_are',
#  'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/No (कुनैमा पनि छैन)': 'community_groups_are',
#  'Community Groups/If other, please specify. (यदि अन्य समुह भएमा, यहाँ उल्लेख गर्नुहोस)': 'community_groups_are',
#  "Community Groups/Women's participation in community/ ward/ municipal meeting and or decision making process (सामुदायिक/वडा/नगरपालिका  बैठक र निर्णय प्रक्रियामा घरको महिलाहरूको सहभागिता)": 'community_groups_are',
#  'Citizenship Number of House Owner (नागरिकता नं)': 'house_owner_basic',
#  'Phone number (फोन नं)': 'meter_घरब_katha',
#  'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)': 'the_house_details',
#  'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)_URL': 'the_house_details',
#  'unique_identity': 'unnamed_unique_identity_your',
#  'Your household unique ID is ${unique_identity}': 'unnamed_unique_identity_your',
#  '__version__': 'meter_घरब_katha',
#  '_id': 'meter_घरब_katha',
#  '_uuid': 'meter_घरब_katha',
#  '_submission_time': 'meter_घरब_katha',
#  '_validation_status': 'meter_घरब_katha',
#  '_notes': 'meter_घरब_katha',
#  '_status': 'meter_घरब_katha',
#  '_submitted_by': 'meter_घरब_katha',
#  '_tags': 'meter_घरब_katha',
#  '_index': 'meter_घरब_katha',
#  'Unnamed: 341': 'unnamed_unique_identity_your',
#  'Unnamed: 342': 'unnamed_unique_identity_your',
#  'Unnamed: 343': 'unnamed_unique_identity_your',
#  'Unnamed: 344': 'unnamed_unique_identity_your',
#  'परिवारको जग्गा in KATHA': 'meter_घरब_katha',
#  'महिला सदस्यको नाममा भएको जग्गा in KATHA': 'meter_घरब_katha',
#  'घरबाट खानेपानी सुविधाको दूरी in METER': 'meter_घरब_katha',
#  'घरबाट स्वास्थ्य संस्थाको दुरी in METER': 'meter_घरब_katha',
#  '(घरबाट बजारको दुरी in METER': 'meter_घरब_katha',
#  '(नजिकैको शौचालय र घरको दुरी in METER': 'meter_घरब_katha',
#  '(Distance to safe Shelter in METER)': 'resources_access_various'}

# %%
import json

output_file = "auto_standardized_headers.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(auto_labeled, f, indent=4, ensure_ascii=False)

print(f"JSON file generated: {output_file}")
# Out:
# JSON file generated: auto_standardized_headers.json
