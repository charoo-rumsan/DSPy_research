# %% [markdown]
# <a href="https://colab.research.google.com/github/charoo-rumsan/DSPy_research/blob/main/dsy_llm_signature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# Specify the path to your CSV file here
file_path = "/content/first_100_rows (1) - first_100_rows (1).csv.csv"

uploaded_filename = None

# Check if the file exists locally
if os.path.exists(file_path):
    uploaded_filename = file_path
    print(f"Local file '{uploaded_filename}' is ready to be used.")
else:
    print(f"Error: File not found at '{file_path}'. Please ensure the file exists at this path.")
# Out:
# Local file '/content/first_100_rows (1) - first_100_rows (1).csv.csv' is ready to be used.

# %%
import csv
import os
from pathlib import Path
import polars as pl

class HeaderExtractor:
    def __init__(self):
        self.supported_formats = ['.csv', '.tsv', '.txt']

    def extract_headers_from_file(self, file_path: str):
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"File not found: {file_path}")

        file_ext = Path(file_path).suffix.lower()
        if file_ext not in self.supported_formats:
            raise ValueError(f"Unsupported file format: {file_ext}")

        headers = self._extract_headers(file_path)
        print(f"✅ Extracted {len(headers)} headers from file.")

        return headers

    def _extract_headers(self, file_path: str):
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            sample = f.read(1024)
            f.seek(0)
            delimiter = csv.Sniffer().sniff(sample).delimiter
        df = pl.read_csv(file_path, separator=delimiter, n_rows=0)
        return df.columns

# %%
import json

# Instantiate the HeaderExtractor
extractor = HeaderExtractor()

# Assuming 'uploaded_filename' holds the path to your CSV file from earlier steps
if 'uploaded_filename' in locals() and uploaded_filename:
    # Extract headers using the new class
    extracted_headers = extractor.extract_headers_from_file(uploaded_filename)

    print("\nHeaders extracted using HeaderExtractor:")
    print(extracted_headers)

    # Save to JSON file
    output_filename = 'extracted_headers.json'
    with open(output_filename, 'w') as f:
        json.dump(extracted_headers, f, indent=4)
    print(f"\nHeaders also saved to {output_filename}")

else:
    print("No CSV file was uploaded. Please upload a file first.")
# Out:
# ✅ Extracted 353 headers from file.
#
# Headers extracted using HeaderExtractor:
# ['', 'start', 'end', 'today', 'username', 'simserial', 'subscriberid', 'deviceid', 'phonenumber', 'General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)', 'General Questions/Municipality and Ward Details/Ward Number (वडा नं .)', 'General Questions/Municipality and Ward Details/Ward Number (वडा नं )', 'General Questions/Name of the Tole (सर्वेक्षण भैरहेको स्थानको नाम)', 'General Questions/House No. (घर नं)', 'GPS Coordinates', 'General Questions/_GPS Coordinates_latitude', 'General Questions/_GPS Coordinates_longitude', 'General Questions/_GPS Coordinates_altitude', 'General Questions/_GPS Coordinates_precision', 'General Questions/Do I have your consent to conduct this survey? (के यो सर्भे गर्नमा तपाइको सहमति छ?)', 'Basic Details of House Owner/Information on house owner/Name of the house owner (घरमुलीको नाम)', 'Basic Details of House Owner/Information on house owner/Age of the house owner (घरमुलीको उमेर)', 'Basic Details of House Owner/Information on house owner/Marital status of house owner (घरमुलीको वैवाहिक स्थिति)', 'Basic Details of House Owner/Information on house owner/Gender of house owner (घरमुलीको बिवरण)', 'Basic Details of House Owner/Information on house owner/Is the house owner differently abled? के घर मालिक फरक रूपमा सक्षम हुनहुन्छ?', 'Basic Details of House Owner/Language and Ethnicity/Mother Tongue (मातृभाषा)', 'Basic Details of House Owner/Language and Ethnicity/If other, specify here. (यदि अन्य मातृभाषा भएमा, यहाँ उल्लेख गर्नुहोस)', 'Basic Details of House Owner/Language and Ethnicity/What is the ethnicity of the family? (परिवार कुन जातिमा पर्नुहुन्छ?)', 'Basic Details of House Owner/Language and Ethnicity/If other, please specify (यदि अन्य भए, यहाँ उल्लेख गर्नुहोस्)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)', 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female  ...
#
# Headers also saved to extracted_headers.json

# %%
# !pip install dspy-ai
import dspy
# Out:
# Collecting dspy-ai
#   Downloading dspy_ai-3.0.4-py3-none-any.whl.metadata (285 bytes)
# Collecting dspy>=3.0.4 (from dspy-ai)
#   Downloading dspy-3.0.4-py3-none-any.whl.metadata (8.4 kB)
# Collecting backoff>=2.2 (from dspy>=3.0.4->dspy-ai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (1.5.2)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (2.8.1)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (2025.11.3)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (3.11.4)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (2.32.4)
# Collecting optuna>=3.4.0 (from dspy>=3.0.4->dspy-ai)
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (2.12.3)
# Collecting magicattr>=0.1.6 (from dspy>=3.0.4->dspy-ai)
#   Downloading magicattr-0.1.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting litellm>=1.64.0 (from dspy>=3.0.4->dspy-ai)
#   Downloading litellm-1.80.7-py3-none-any.whl.metadata (30 kB)
# Collecting diskcache>=5.6.0 (from dspy>=3.0.4->dspy-ai)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting json-repair>=0.30.0 (from dspy>=3.0.4->dspy-ai)
#   Downloading json_repair-0.54.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (9.1.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (4.11.0)
# Collecting asyncer==0.0.8 (from dspy>=3.0.4->dspy-ai)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (6.2.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (3.1.2)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (13.9.4)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (11.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.4->dspy-ai) (3.6.0)
# Collecting gepa==0.0.17 (from gepa[dspy]==0.0.17->dspy>=3.0.4->dspy-ai)
#   Downloading gepa-0.0.17-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.4->dspy-ai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.4->dspy-ai) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.4->dspy-ai) (4.15.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (3.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (8.3.1)
# Collecting fastuuid>=0.13.0 (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting grpcio<1.68.0,>=1.62.3 (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai)
#   Downloading grpcio-1.67.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (4.25.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.22.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.0.4->dspy-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.0.4->dspy-ai) (0.12.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.4->dspy-ai) (1.17.2)
# Collecting colorlog (from optuna>=3.4.0->dspy>=3.0.4->dspy-ai)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.4->dspy-ai) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.4->dspy-ai) (2.0.44)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.4->dspy-ai) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.4->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.4->dspy-ai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.4->dspy-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.4->dspy-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.4->dspy-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.4->dspy-ai) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy>=3.0.4->dspy-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy>=3.0.4->dspy-ai) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy>=3.0.4->dspy-ai) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.29.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy>=3.0.4->dspy-ai) (0.1.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy>=3.0.4->dspy-ai) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.4->dspy-ai) (1.2.0)
# Downloading dspy_ai-3.0.4-py3-none-any.whl (1.1 kB)
# Downloading dspy-3.0.4-py3-none-any.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.2/285.2 kB 1.5 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading gepa-0.0.17-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 3.6 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.5 MB/s eta 0:00:00
# Downloading json_repair-0.54.2-py3-none-any.whl (29 kB)
# Downloading litellm-1.80.7-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 6.2 MB/s eta 0:00:00
# Downloading magicattr-0.1.6-py2.py3-none-any.whl (4.7 kB)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 9.8 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 9.2 MB/s eta 0:00:00
# Downloading grpcio-1.67.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 10.8 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: magicattr, json-repair, grpcio, gepa, fastuuid, diskcache, colorlog, backoff, asyncer, optuna, litellm, dspy, dspy-ai
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.76.0
#     Uninstalling grpcio-1.76.0:
#       Successfully uninstalled grpcio-1.76.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires grpcio>=1.71.2, but you have grpcio 1.67.1 which is incompatible.
# Successfully installed asyncer-0.0.8 backoff-2.2.1 colorlog-6.10.1 diskcache-5.6.3 dspy-3.0.4 dspy-ai-3.0.4 fastuuid-0.14.0 gepa-0.0.17 grpcio-1.67.1 json-repair-0.54.2 litellm-1.80.7 magicattr-0.1.6 optuna-4.6.0

# %%
import dspy
from dspy.teleprompt import BootstrapFewShot


# Set up the language model
# You can choose other models like dspy.Google("models/gemini-pro") or dspy.Cohere()

llm =  dspy.LM(model="ollama/llama3.1:latest",
         base_url= "", api_key='')
dspy.configure(lm=llm)

print("DSPy configured with ollama.")
# Out:
# DSPy configured with ollama.

# %%
math = dspy.ChainOfThought("question -> answer")
print(math(question="What is ollama?"))
# Out:
# Prediction(
#     reasoning="Ollama is a deep learning model that can be used to generate text based on a given prompt. It was created by combining a generative adversarial network (GAN) with a recurrent neural network (RNN). Ollama's primary function is to learn the structure and patterns of language, allowing it to produce coherent and context-specific text.",
#     answer='Ollama'
# )

# %% [markdown]
# DSPy Signature

# %%
# High-quality few-shot examples — these are CRUCIAL for messy Nepali/ODK headers
examples = [
    dspy.Example(
        raw_header="General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)",
        clean_label="municipality_name"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="General Questions/_GPS Coordinates_latitude",
        clean_label="latitude"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुहुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Female (महिला)",
        clean_label="widowed_female"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Household Members/Number of household members/People living in this house for more than 6 months",
        clean_label="household_size"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Livelihood/Income Sources/Main Source of Income (आयको मुख्य स्रोत)",
        clean_label="main_income_source"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Disability/Does anyone in the household have a disability?/Type of Disability/Seeing (even with glasses)",
        clean_label="disability_vision"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="note_001_start_time",
        clean_label="survey_start_time"
    ).with_inputs("raw_header"),
]

# %%
class CleanHeaderToLabel(dspy.Signature):
    """You are an expert in cleaning and standardizing CSV column headers from humanitarian/nepali surveys.
    Convert messy, nested, multilingual headers into short, clean, snake_case English labels.
    Remove redundancy, keep only meaningful parts, prefer clarity and brevity.
    Never include numbers unless they are part of the meaning (e.g., age_0_5).
    Always use snake_case. Never use camelCase or spaces."""

    raw_header: str = dspy.InputField(desc="Original messy CSV header, may contain slashes, parentheses, Nepali text, repetition")
    clean_label: str = dspy.OutputField(desc="Clean snake_case English label, e.g. widowed_female, latitude, household_head_name")

# Compile with few-shot examples
# The issue seems to be with dspy.Example objects not being JSON serializable when passed to litellm.
# As a temporary workaround to make the code run, the `examples` parameter is removed.
# This will disable few-shot learning for now.
cleaner = dspy.ChainOfThought(CleanHeaderToLabel)

# Your huge list of headers
messy_headers = extracted_headers

# Generate clean labels
for header in messy_headers:
    result = cleaner(raw_header=header.strip().strip("'"))
    print(f"{header!r} -> '{result.clean_label}'")
# Out:
# '' -> 'champa_development_board'
# 'start' -> 'start
#
#
# ### System:'
# 'end' -> 'coca-cola'
# 'today' -> 'today'
# 'username' -> 'username
#
# ### System:'
# 'simserial' -> 'sim_serial'
# 'subscriberid' -> 'subscriberid'
# 'deviceid' -> 'device_id'
# 'phonenumber' -> 'phone_number'
# 'General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)' -> 'municipality_name
#
# ### System:'
# 'General Questions/Municipality and Ward Details/Ward Number (वडा नं .)' -> 'ward_number
#
# ### System:
# Now, we can provide the completed output.'
# 'General Questions/Municipality and Ward Details/Ward Number (वडा नं )' -> 'ward_number'
# 'General Questions/Name of the Tole (सर्वेक्षण भैरहेको स्थानको नाम)' -> 'general_questions_tole_name'
# 'General Questions/House No. (घर नं)' -> 'house_number'
# 'GPS Coordinates' -> 'gps_coordinates'
# 'General Questions/_GPS Coordinates_latitude' -> 'latitude
#
# ### System:'
# 'General Questions/_GPS Coordinates_longitude' -> 'general_questions_latitude_longitude'
# 'General Questions/_GPS Coordinates_altitude' -> 'geospatial_data_altitude'
# 'General Questions/_GPS Coordinates_precision' -> 'general_questions_precision'
# 'General Questions/Do I have your consent to conduct this survey? (के यो सर्भे गर्नमा तपाइको सहमति छ?)' -> 'general_questions
#
# ### System:'
# 'Basic Details of House Owner/Information on house owner/Name of the house owner (घरमुलीको नाम)' -> 'house_owner_name'
# 'Basic Details of House Owner/Information on house owner/Age of the house owner (घरमुलीको उमेर)' -> 'house_owner_info'
# 'Basic Details of House Owner/Information on house owner/Marital status of house owner (घरमुलीको वैवाहिक स्थिति)' -> 'house_owner_marital_status
#
# ### System:'
# 'Basic Details of House Owner/Information on house owner/Gender of house owner (घरमुलीको बिवरण)' -> 'house_owner_gender'
# 'Basic Details of House Owner/Information on house owner/Is the house owner differently abled? के घर मालिक फरक रूपमा सक्षम हुनहुन्छ?' -> 'house\_owner\_differently_abled'
# 'Basic Details of House Owner/Language and Ethnicity/Mother Tongue (मातृभाषा)' -> 'house_owner_language'
# 'Basic Details of House Owner/Language and Ethnicity/If other, specify here. (यदि अन्य मातृभाषा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'house_owner_details'
# 'Basic Details of House Owner/Language and Ethnicity/What is the ethnicity of the family? (परिवार कुन जातिमा पर्नुहुन्छ?)' -> 'house_owner language ethnicity
#
# ### System:
# Given the final cleaned label list, we see that the process was successful in identifying meaningful parts of the header and standardizing them for a clearer understanding in subsequent analyses or use cases.'
# 'Basic Details of House Owner/Language and Ethnicity/If other, please specify (यदि अन्य भए, यहाँ उल्लेख गर्नुहोस्)' -> 'basic_details_house_owner, language, ethnicity'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'female_members_age_0_to_4'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'female_age_5_to_9'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'age_group_female_10_14_count'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'widowed_female_15_to_19
#
# ### System:
# The reasoning behind this choice is that it directly translates the specific part of the header into English, specifies that it's about female widows within a certain age range, and follows the snake_case convention.
#
# ### System:
# Therefore, considering all parts of the header and applying our standardization rules:'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'family_members_details_no_female_20_to_24'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'age_group_female_25_to_29'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'family_members, age_group, female_30_34'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'family_members
# total_family_members
# age_group_details
# female_members_35_to_39_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'age_group_40_44_female'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'age_group_female'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'family_members_details/female_age_50_54'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला सद' -> '`widowed_female_55_59`'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'family_members_60_64_female_count
#
# ### System:'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'female_65_to_69'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'female_members_70_74'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'family_member_details_total_family_members_age_group_details age_group_female female_members_75_plus_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/total_female' -> 'family_members_details_female_age_group'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Female is ${total_female}' -> 'family_members_details'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_age_0_5'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_members_5_to_9'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'family_members_details/total_family_members_age_group_male/male_member_10_to_14_years
#
# ### System:
# The output fields are now complete.'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'family_members_details/male_15_to_19'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_age_20_to_24_members'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'age_group_male_25_to_29'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_members_age_30_to_34
#
# ### System:
# Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'age_group_male_35_to_39'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_40_44_age_group'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_members_age_45_49'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_age_50_54'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने पुरुष  सदस्यहरुको संख्या)' -> 'male_age_55_59'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'male_family_members_60_64'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'family_members age_group_male age_65_69_male'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'family_members_details
# total_number_family_members
# age_group_details
# age_group_male_70_74
# male_members_age_group_70_74
#
# ### System:'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'family_and_age_group, age_group_male, male_above_75_count'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/total_male' -> 'family_members_details_total_age_group_male
#
# ### System's output fields:'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Male is ${total_male}' -> 'family_members_details_total_number'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या )' -> 'age_0_to_4'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या' -> 'family_members_details
# total_family_member_age_group_details
# other_age_group
# undifferentiated_members_age_5_to_9'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या) )' -> 'other_gender_members_10_to_14'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'other_gender_members_age_15_to_19'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'family_members_age_group_others_other_gender_20_to_24'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'family_members_details_no_other_gender_25_to_29
#
# ### System:'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'other_gender_members_30_to_34_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'others_35_to_39'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'other_gender_40_44'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'age_group_others'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'other_gender_age_50_to_54'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'family_members_details
# age_group_others
# total_family_members_and_age_group_details
# number_of_other_gender_members_of_the_age_group_55_to_59_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'other_gender_members_60_64'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_age_65_to_69'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'age_group_70_74_not_identified_gender'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'total_family_members_and_age_group_details_other_gender_75_plus'
# 'Family Members Details/Total Number of Family Members and Age Group Details/total_other' -> 'family_members_details_and_age_group_details'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Others is ${total_other}' -> 'family_members_details
# total_family_members
# age_group_details
# total_others'
# 'Family Members Details/Total Number of Family Members and Age Group Details/total_members' -> 'family_members age_group
#
# ### System:'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of family members is ${total_members}' -> 'family_members_count
#
# ### System:'
# 'Family Members Details/Identity Revealing Document/Do the house members have identity revealing documents? (के तपाइँ र तपाईको घरका सदस्यहरुसंग आफ्नो परिचय खुल्ने कागजात छ?)' -> 'identity_revealing_documents
#
# ### System:'
# 'Family Members Details/Identity Revealing Document/If few members do not have, specify the number. (यदि कसैको छैन भने, कति जनाको छैन यहाँ उल्लेख गर्नुहोस)' -> 'family_members'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Pregnant and Lactating (गर्भवती तथा स्तनपान गराउने)' -> 'sensitive_population'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Widowed (विदुवा/विदुर)' -> '1. `sensitive_population`
# 2. `widowed`'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Chronically ill (दिर्घकालिन रोग भएको)' -> 'sensitive_population_chronically_ill'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)' -> 'sensitive_population_in_house
# people_with_disability'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Single Woman (एकल महिला)' -> 'sensitive_population_single_woman'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/None of the above (माथिका कुनै पनि छैन)' -> 'sensitive_population
#
# ### System:'
# 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, specify the number. (यदि गर्भवती र स्तनपान गराउने हुनुहुन्छ भने, कति जना हुनुहुन्छ?' -> 'family_members_details, sensitive_population_house, pregnant_lactating_status, lactating_number'
# 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, are they differently abled? (यदि गर्भवती तथा स्तनपान गराउने भए, उहाहरु अपाङ्गता भएको वा फरक रुपमा सक्षम हुनुहुन्छ?)' -> 'family_details'
# 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If yes, please write down the number of people with disability pregnant and lactating woman (यदि हुनुन्छ भने, अपाङ्गता भएको वा फरक रुपमा सक्षम कति जना हुनुन्छ?' -> 'disabled_pregnant_lactating
#
# ### Completed'
# 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Female (महिला)' -> 'The final cleaned label would be: widowed_female'
# 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Male (पुरुष)' -> 'widowed_male'
# 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Other (अन्य)' -> 'sensitive widowed_gender other'
# 'Family Members Details/Sensitive Population in the house/Widowed/How many members in the family members are widowed? (घरका कतिजना सदस्य विधवा/विदुर हुनुहुन्छ?)' -> '{sensitive_family_widowed}'
# 'Family Members Details/Sensitive Population in the house/Single woman/If single woman, how many members in the family are single woman? (यदि एकल महिला भएमा, कतिजना सदस्य एकल महिलामा पर्नुहुन्छ?)' -> 'family_members_details
# sensitive_population_in_house
# single_woman'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)' -> 'differently_abled_female'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)' -> 'differently_abled_family_member_gender'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)' -> 'differently_abled_family_member_gender'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, how many members in the family are people with disability? (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, घरमा कतिजना फरक रुपमा सक्षम हुनुहुन्छ?)' -> 'people_with_disability'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Physical disabilities (शारीरिक असक्षमता)' -> 'sensitive_population_type'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Visual disabilities (दृष्टि असक्षमता)' -> 'differently_abled_type
#
# ### System:'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing disabilities (श्रवण असक्षमता)' -> 'hearing_disability'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing-Visual disabilities (श्रवण-दृश्य असक्षमता)' -> 'disabled_individuals_type'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Speaking disabilities (बोल्ने असक्षमता)' -> 'speaking_disability'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Mental disabilities (मानसिक असक्षमता)' -> 'family_members_details, sensitive_population_house, has_disability, type_of_disability'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Intellectual disabilities (बौद्दिक  असक्षमता)' -> 'sensitive_population
# differently_abled
# intellectual_disability'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Multiple disabilities (धेरै असक्षमताहरु)' -> 'family_details, sensitive_population, differently_abled, physical_disability, mental_disability, multiple_disabilities
#
# ### System:'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Do the people with disability family member have identity revealing document provided by municipality? (के शारिरिक तथा मानसिक अपांगता भएको परिचय पत्र पालिका बाट प्राप्त गर्नुभएको छ?)' -> 'family_members_details
# sensitive_population
# differently_abled
# disability_identity_document'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Red Card (रातो कार्ड)' -> 'disability_card_type'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Blue Card (निलो कार्ड)' -> 'sensitive_population_differently_abled'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Yellow Card (पहेलो कार्ड)' -> 'sensitive_population_disability_card_type
#
# ### System:'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/White Card (सेतो कार्ड)' -> 'disability_card_type'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)' -> 'chronic_family_member_gender
#
# ### Me:'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)' -> 'family_members_details
# sensitive_population
# chronically_ill
# specify_chronically_ill_gender
# male
#
# ### System:'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)' -> 'family_members_details
# sensitive_population
# chronically_ill
# gender_of_chronically_ill_family_members
# other
#
# ### System:'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, how many members in the family are chronically ill? (यदि दिर्घकालिन रोग भएमा, घरका कतिजना सदस्यहरुलाइ दिर्घकालिन रोग छ?)' -> 'family_details
# sensitive_population
# chronic_condition
# family_members_with_chronic_conditions'
# 'Family Members Details/Education Status/Literacy/Total literate female members in the house ( घरमा कुल साक्षर महिला सदस्यहरू)' -> 'family_education_literacy_literate_female_members'
# 'Family Members Details/Education Status/Literacy/Total literate male members in the house ( घरमा कुल साक्षर पुरुष सदस्यहरू)' -> 'male_literate_household_members'
# 'Family Members Details/Education Status/Literacy/Total literate other gender members in the house ( घरमा कुल साक्षर महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यहरू)' -> 'education_status, literacy_status
#
# ### Step 6: Confirm completion based on the structured interaction format.'
# 'Family Members Details/Education Status/Literacy/total_literate' -> 'family_members_details
# education_status
# literacy'
# 'Family Members Details/Education Status/Literacy/Total literate members of age between (15-60) years in the house (घरमा (१५-६०) वर्ष उमेर समुहका कुल साक्षर सदस्यहरू)' -> 'literacy_15_60'
# 'Family Members Details/Education Status/Total Number of Literate Family Members is ${total_literate}' -> 'The cleaned version of the header in snake_case format would be "family_details_education_status".'
# 'Family Members Details/Education Status/total_illiterate' -> 'education_status, total_illiterate'
# 'Family Members Details/Education Status/Total Number of Illiterate Family Members is ${total_illiterate}' -> 'illiterate_family_members'
# 'Family Members Details/Education Status/Education Level/Total family members who are not eligible for schooling  (परिवारका कुल सदस्यहरू जो पढ्न योग्य नभएका)' -> 'family_members_details, family_member_education_status, family_member_education_level, total_family_members_not_eligible_schooling'
# 'Family Members Details/Education Status/Education Level/Total family members with other/non-formal education (अन्य/अनौपचारिक शिक्षा लिएका परिवारका कुल सदस्यहरू)' -> 'education_level_other_nonformal'
# 'Family Members Details/Education Status/Education Level/Total family members whose education level is not known ( कुल परिवारका सदस्य जसको शिक्षा स्तर थाहा छैन)' -> 'family_members_details, education_status, education_level, unknown_education
#
# ### System:'
# 'Family Members Details/Education Status/Education Level/Total family members at primary level of schooling (कक्षा ५ सम्म) विद्यालयको प्राथमिक तहमा (पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> 'family_members_details_education_level_at_primary_up_to_class_5
#
# ### System:'
# 'Family Members Details/Education Status/Education Level/Total family members at Lower Secondary level of schooling (विद्यालयको निम्न माध्यमिक तहमा  (कक्षा ८ सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> 'total_family_members_lower_secondary'
# 'Family Members Details/Education Status/Education Level/Total family members at Secondary level of schooling (विद्यालयको  माध्यमिक तहमा ((कक्षा ९ वा १० सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> 'education_level_9_to_10
#
# ### System:'
# 'Family Members Details/Education Status/Education Level/Total family members at SLC or Equivalent level of schooling (SLC वा सो सरह स्तरमा पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> 'family_members_details, education_status, education_level, total_family_members_at_slc'
# 'Family Members Details/Education Status/Education Level/Total family members at Intermediate or Equivalent level of schooling (+२ पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> 'education_status'
# 'Family Members Details/Education Status/Education Level/Total family members at Bachelor or Equivalent level of schooling (ब्याचलर वा सो सरह पढेका/पढ्ने परिवारका कुल सदस्यहरू)' -> 'total_family_members_bachelor'
# 'Family Members Details/Education Status/Education Level/Total family members at Masters / Ph.D level of education (मास्टर्स/पी.एच.डी पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> 'family_members_details_education_level_total_family_masters_phd'
# 'Other Family Members Details/Are there any other families living in the same house? (तपाईको घरमा अन्य कुनै परिवार बस्नुहुन्छ?)' -> 'other_family_members_details
#
# ### System:'
# 'Other Family Members Details/If yes, how many female members are there? (यदि बस्नुहुन्छ भने, महिला सदस्य कतिजना हुनुहुन्छ?)' -> 'female_family_members'
# 'Other Family Members Details/How many male members are there? (यदि बस्नुहुन्छ भने, पुरुष सदस्य कतिजना हुनुहुन्छ?)' -> 'male_member_count'
# 'Other Family Members Details/How many members of other gender are there ? (यदि बस्नुहुन्छ भने, अन्य महिला वा पुरुष भनि पहिचान नगर्ने सदस्य कतिजना हुनुहुन्छ?)' -> 'other_family_members_details_other_gender
#
# ### System:'
# 'Economic Condition of the House Owner Family/Major Occupation/What is the primary occupation of your family? (तपाईको घरको प्रमुख पेशा कुन हो?)' -> 'house_owner_family_primary_occupation'
# 'Economic Condition of the House Owner Family/Major Occupation/If other, please specify (यदि अन्य मुख्य पेशा भए, यहाँ उल्लेख गर्नुहोस्)' -> 'house_owner_family_economic_condition'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Agriculture and Livestock (कृषि तथा पशुपालन)' -> 'house_owner_family_secondary_occupation'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/On-farm Daily Wage Worker (कृषि क्षेत्रमा दैनिक ज्याला मजदुर)' -> 'economic_condition_house_owner_family secondary_occupation family_supporting_occupation'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Off-farm Daily Wage Worker (गैर कृषि क्षेत्रमा दैनिक ज्याला मजदुर)' -> 'economic_condition'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Business (व्यापार तथा व्यवसाय)' -> 'occupation_of_house_owner_family
#
# ### System:'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Government Service (सरकारी सेवा)' -> 'occupation'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Private Job (निजी सेवा)' -> 'economic_condition'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Foreign Employment/Remittance (वैदेशिक रोजगार)' -> 'economic_condition_house_owner_family_occupation_foreign_employment'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Other (अन्य)' -> 'secondary_occupation_family'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/No supporting occupation (कुनै सहायक पेशा छैन)' -> 'economic_condition, supporting_occupation
#
# ### Status:'
# 'Economic Condition of the House Owner Family/Supporting Occupation/If other, please specify (यदि अन्य सहायक पेशा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'economic_condition/supporting_occupation/other/house_owner_family'
# 'Economic Condition of the House Owner Family/Supporting Occupation/Number of unemployed members in the household (घरमा कतिजना वेरोजगार हुनुहुन्छ?)' -> 'economic_condition_house_owner_family supporting_occupation number_unemployed_members
#
# ### System:'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Do you or your family members own land? (के तपाइँ र तपाइको परिवारको नाममा जग्गा-जमिन छ?)' -> 'do_you_own_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/How much land do you or your family hold? (तपाइँ र तपाईको परिवारको जग्गा कति छ?)' -> 'economic_condition_land_holding'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)' -> 'unit_of_measurement'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other type, please specify the type of land (यदि अन्य भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'land_holding_details'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)' -> 'land_use_type'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)' -> 'economic_condition
# land_holding_details
# family_members
# land_use_type
# cultivation_area
#
# ### System:'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Forested Area (वन क्षेत्र)' -> 'economic_condition
# land_holding_details
# forested_area
#
# ### System:'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Open Space (खुल्ला स्थान)' -> 'land_use_type'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Commercial Purpose (व्यापारिक क्षेत्र)' -> 'economic_condition
# land_ownership_details
# commercial_purpose
#
# ### System:'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)' -> 'land_use_status'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Other (अन्य)' -> 'economic_condition, land_ownership_details, household_land_use_type'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other land type, please specify the type of land (यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'land_holding_details'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Do the female members of the house own the land? (घरको महिला सदस्यको नाममा जग्गा-जमिन छ?)' -> 'household_economic_condition, female_land_ownership'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Total land held by female of the house (घरको महिला सदस्यको नाममा भएको जग्गा कति छ?)' -> 'land_held_by_female_house_members'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)' -> 'land_measurement_unit'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type that helds by female, please specify the type of land (महिला सदस्यले यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'economic_status_of_house_owner_family
# land_holding_by_female_members
# other_land_type_held_by_female
#
# The reasoning behind these labels includes:
# - **economic_status_of_house_owner_family**: This captures the essence of economic conditions tied to house ownership, making it a clear and direct label.
# - **land_holding_by_female_members**: Preserving "female members" ensures that gender is recognized as an important aspect in this category, which could be useful for analysis purposes.
# - **other_land_type_held_by_female**: Similar to the previous point, specifying "held by female" maintains relevance while suggesting it's a secondary or specific case not covered under general land holding categories.'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)' -> 'type_of_land_holding_by_female'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)' -> 'land_holding_by_female'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Forested Area (वन क्षेत्र)' -> 'land_holding_by_female'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Open Space (खुल्ला स्थान)' -> 'economic_condition, land_holding, land_holding_female, female_landholding_types, open_space
#
# ### System:'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Commercial Purpose (व्यापारिक क्षेत्र)' -> 'economic_condition
# land_holding
# female_land_ownership
# commercial_purpose'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)' -> 'economic_condition, land_holding, land_holding_by_female, barren_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Other (अन्य)' -> 'economic_condition_women_land_ownership type_of_land_holding_by_female other
#
# ### System:'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type, specify here. (यदि अन्य भू-उपयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'economic_condition_family
# land_holding_female_members
#
# ### System:
# With these considerations, we can now provide the output as per the instructions.'
# 'Economic Condition of the House Owner Family/Income and Expenditure/Annual income of the family (वार्षिक आम्दानी)' -> 'house_income'
# 'Economic Condition of the House Owner Family/Income and Expenditure/Monthly Expenditure of the house  (घरको मासिक खर्च)' -> 'monthly_expenditure'
# 'Economic Condition of the House Owner Family/Income and Expenditure/Yearly saving of the house  (घरको वार्षिक बचत)' -> 'house_yearly_saving'
# 'Economic Condition of the House Owner Family/Saving, Credit and Loan/Have you taken loan from the financial institutions? (के तपाइले कुनै वित्तीय संस्था बाट ऋण लिनुभएको छ?)' -> 'economic_condition_house_owner_family, saving_credit_loan, taken_loan_from_financial_institutions
#
# ### System:'
# 'Economic Condition of the House Owner Family/Saving, Credit and Loan/Covered by subsidized loan targeted for women/marginalized group (घरको  महिला/सीमान्तकृत समूहका लागि लक्षित सहुलियतपूर्ण ऋण पाएको छ?)' -> 'economic_condition_loan_subsidy_women_marginalized
#
# ### System:'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Is any family member receiving reservations, allowances and special privilege systems? (के तपाइको घरको कुनै सदस्यले कुनै आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)' -> 'special_privilege'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen (ज्येष्ठ नागरिक)' -> 'senior_citizen_reservation'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Dalit (ज्येष्ठ नागरिक दलित)' -> 'affirmative_action'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Single Women (ज्येष्ठ नागरिक एकल महिला)' -> 'economic_condition'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Widowed (विधवा/ एकल महिला)' -> 'economic_condition_house_owner_family, reservations_allowances_special_privileges, widowed_female
#
# ### System:
# After careful analysis, we have broken down the complex raw header into three clean labels: `economic_condition_house_owner_family`, `reservations_allowances_special_privileges`, and `widowed_female`. These labels are in snake_case English and accurately represent the original meaning.'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)' -> 'economic_condition_house_owner_family, reservations_allowances_privileges, physical_and_mental_disability'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Dalit Child Allowance (दलित बाल बालिका)' -> 'dalit_child_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Pension (पेन्सन)' -> 'economic_condition_of_house_owner_family
# reservations_allowances_and_special_privilege_system
# type_of_reservation_pension'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Others (अन्य)' -> 'economic_condition_of_house_owner_family reservation_and_allowance_system type_of_reservation_and_allowance
#
# Note: I removed the Nepali text as it's not necessary for the label, and "others" is not included as it's a category within the main system, not a separate label.'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If other type of privilege system, please specify (यदि अन्य किसिमको सुविधाहरु भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'economic_condition, household_head_family, privilege_system, other_privilege_system_specify'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen allowance (वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen dalit allowance (दलित वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'dalit_allowance_recipients'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen single woman allowance (महिला वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'family_members_allowed_single_woman_pension'
# ...
# 'Details on the House/Structure Built and Permit/Age of the house (In years) (घर निर्माण भएको कति वर्ष भयो?)' -> 'built_and_permit_age'
# 'Details on the House/Structure Built and Permit/Number of storey of the house (घरको तल्ला)' -> 'house_storey'
# 'Details on the House/Structure Built and Permit/Is the building designed following building code? (के तपाइले घर बनाउदा भवन निर्माण संहिता पालना गरेर निर्माण गर्नुभएको हो?)' -> 'building_code_followed'
# 'Details on the House/Structure Built and Permit/Have you received a building permit from the municipality? ( नगरपालिकाबाट निर्माण स्वीकृति लिनुभएको छ?)' -> 'house_structure_details_building_permit'
# 'Details on the House/Construction Materials/Type of foundation of the building (तल उल्लेख मध्ये तपाईको घरको जगको निर्माण सामाग्री के-के हुन्)' -> 'house_construction_materials'
# 'Details on the House/Construction Materials/If other type of foundation materials, please specify. (यदि अन्य प्रकारको निर्माण सामग्री भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'construction_materials'
# 'Details on the House/Construction Materials/Please mention the building type of your house (तपाइको घर तल उल्लेख मध्ये कुन किसिमको हो?)' -> 'house_type
#
# ### Completed:'
# 'Details on the House/Construction Materials/If other type of building type, please specify. (यदि अन्य प्रकारको भवन भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'house_building_type_description
#
# ### System:'
# 'Details on the House/Construction Materials/What materials are used for the construction of Wall of your house? (तपाइको घरको भित्ता के ले बनेको छ?)' -> 'wall_construction_materials'
# 'Details on the House/Construction Materials/If other wall type, please specify (यदि अन्य सामग्रीले बनेको भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'house_construction_material_wall_other'
# 'Details on the House/Construction Materials/What materials are used for the construction of Roof of your house? (तपाइको घरको छाना केले निर्माण गरिएको छ?)' -> 'construction_materials'
# 'Details on the House/Construction Materials/If other materials of roof, please specify. (यदि अन्य निर्माण सामग्रीले छाना बनेको भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'house_construction_roof_materials'
# 'Details on the House/Construction Materials/Is the roof easily accessible in case of any emergency? (के तपाइको घरको छतमा सजिलै जान र बस्न मिल्छ?)' -> 'emergency_access'
# 'Details on the House/Current Condition/What is the current condition of your house? (तपाइको घरको अहिलेको अवस्था कस्तो छ?)' -> 'Considering the importance of clarity and brevity, we can remove redundant words while keeping the essence. Since the context is about a house, we'll focus on capturing its condition.
#
# house_current_condition
#
# ### System:'
# 'Details on the House/Current Condition/How is the ground surface of the area in which your house has been built? (तपाईको घर निर्माण भएको जमिनको सतह कस्तो छ?)' -> 'ground_surface'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Raised Plinth and above flood level (उठाएको प्लिन्थ-बाढीको सतह भन्दा माथि)' -> 'added_structure_above_flood_level'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Strong wall (मजबुत पर्खाल)' -> 'strong_wall'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Proper drainage (उचित ढल/जल निकासी)' -> 'house_features
#
# ### Me:'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/None of the above (माथिको कुनै पनि होइन)' -> 'house_features'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years, how many times have you experienced flooding events? (विगत ३० वर्षमा तपाइले कति पटक बाढीका घटनाहरुको अनुभव गर्नुभएको छ?)' -> 'flood_events_past_30_years'
# 'Hazard and Disaster/Historical Damage and Loss/In the past flooding events, what is the maximum depth of flood occurrence surrounding the household? विगतको बाढी घटनामा, घर वरिपरि बाढीको अधिकतम गहिराई कति थियो ?' -> 'flood_depth'
# 'Hazard and Disaster/Historical Damage and Loss/Select the unit of flood depth measurement. (बाढीको गहिराई नाप्ने इकाइ चयन गर्नुहोस्।)' -> 'We'll use snake_case for the label. The main parts are "hazard_disaster", "historical_damage_loss", and "flood_depth_measurement_unit". We can combine them into one label, using underscores to separate words: hazard_disaster_historical_damage_loss_flood_depth_measurement_unit
#
# ### System:'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Death of  household members (परिवारको सदस्यको मृत्यु भएको)' -> 'past_flood_damage'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Missing household members (परिवारको सदस्य हराएको)' -> 'flood_damage_and_missing_members'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Injured household members (परिवारको सदस्य घाइते हुनुभएको)' -> 'flood_damage_past_30_years'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/People displaced (विस्थापित)' -> 'historical_damage_flooding'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to house (घरमा क्षति भएको)' -> 'historical_damage_and_loss
#
# ### System:'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Land affected (जमिन क्षति भएको)' -> 'historical_flooding_damage'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Livestock affected (पशु क्षति भएको)' -> 'hazard_and_disaster_damage_past_30_years_flooding_events
# livestock_kshati_bhaya'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Farmland affected (खेति जमिनमा क्षति)' -> 'disaster_damage,flooding_events_farm'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to stored food stock (भण्डारण गरिएको खाद्यान्न क्षति)' -> 'historical_damage, damage_to_stored_food_stock'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Non-Structural Damage (गैर-संरचनात्मक क्षति)' -> 'past_30_years_flooding_damage'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Loss of other livelihood options ( such as loss of job, business, other than agriculture)' -> 'flood_damage'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/No any damage (कुनै पनि क्षति नभएको)' -> 'past_flooding_damage'
# 'Hazard and Disaster/Historical Damage and Loss/Number of people death (मृत्यु हुनेको संख्या)' -> 'death_toll
#
# ### System:'
# 'Hazard and Disaster/Historical Damage and Loss/Number of missing family members (हराएका परिवारको सदस्यको संख्या)' -> 'number_of_missing_family_members'
# 'Hazard and Disaster/Historical Damage and Loss/Number of injured family members (घाइतेको संख्या)' -> 'hazard_disaster,historical_damage,number_of_injured_family_members
#
# ### System:'
# 'Hazard and Disaster/Historical Damage and Loss/Number of people displaced (विस्थापित संख्या)' -> 'hazard_disaster_displaced_number'
# 'Hazard and Disaster/Historical Damage and Loss/Total area of farmland affected (कुल खेति जमिन क्षति)' -> 'hazard_disaster_damage'
# 'Hazard and Disaster/Historical Damage and Loss/Unit of measurement of affected farmland area (प्रभावित खेति जमिन क्षेत्रको मापनको इकाइ)' -> 'hazard_and_disaster_unit_of_measurement'
# 'Hazard and Disaster/Historical Damage and Loss/Estimated agricultural loss (कुल कृषि क्षति)' -> 'agricultural_loss'
# 'Hazard and Disaster/Historical Damage and Loss/Type of damage to the house (घरको क्षतिको प्रकार)' -> 'type_of_damage_to_house'
# 'Hazard and Disaster/Historical Damage and Loss/Total livestock loss (कुल पशु क्षतिको संख्या)' -> 'total_livestock_loss'
# 'Hazard and Disaster/Historical Damage and Loss/Estimated livestock loss NPR (कुल पशु क्षति)' -> 'damage_and_loss_estimated_livestock_npr
#
# This label maintains relevance, includes specificity about what's being measured (damage and loss), incorporates the key detail of estimated livestock, and specifies the currency. It also follows the required snake_case formatting.
#
# ### System:
# In summary, after careful consideration of clarity, brevity, and the need to maintain snake_case conventions for a clean label:'
# 'Hazard and Disaster/Historical Damage and Loss/Total loss of stored food KG (भण्डारण गरिएको खाद्यान्न क्षति)' -> 'historical_damage_and_loss
# total_loss_of_stored_food_weight'
# 'Hazard and Disaster/Historical Damage and Loss/Total Estimated loss NPR (कुल अनुमानित क्षति)' -> 'hazard_and_disaster_historical_damage
#
# ### Completed:'
# 'Hazard and Disaster/Historical Damage and Loss/If loss of other livelihood options, please specify. अन्य जीविकोपार्जनका विकल्पहरू गुमाएमा, कृपया यहाँ उल्लेख गर्नुहोस्।' -> 'hazard_damage_loss_lost_alternative_livelihood'
# 'Hazard and Disaster/Knowledge and Training in Disaster/Have any family members received training on disaster? (के तपाइँ वा तपाईको परिवारको सदस्यले विपद सम्बन्धी तालिम लिनुभएको छ?)' -> 'hazard_and_disaster/training_on_disaster/has_family_member_received_training'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/First Aid (प्राथमिक उपचार)' -> 'Considering the above reasoning, we can create clean labels as follows:
#
# 1. `hazard_disaster` for the first part.
# 2. Since we're keeping the training type question due to its specificity, we'll label it as `disaster_training_types`.
# 3. For "First Aid," we'll simply use `first_aid`.
#
# ### System:'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Search and rescue (खोज तथा उद्दार)' -> 'search_and_rescue'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Simulation and drill exercise (सिमुलेशन र ड्रिल)' -> 'hazard_simulation'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Other Disaster related training (विपद सम्बन्धी अन्य तालिम)' -> 'other_disaster_training'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If other disaster related trainings received, please specify what type of trainings. (यदि विपद सम्बन्धी अन्य तालिम भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'disaster_training'
# 'Hazard and Disaster/Aftermath of Past Disaster/Access to social assistance in the aftermath of past disaster (विगतको प्रकोप पछि सामाजिक सहायता प्राप्त भएको थियो?)' -> 'access_to_social_assistance'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/DRRM committee of ward/municipality (पालिका वा वडाको विपद सम्बन्धी समितिमा)' -> 'community_group_membership'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Women group (महिला समुह)' -> 'community_groups'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Youth group (युवा समुह)' -> 'youth_group'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Child group (बाल समुह)' -> 'community_groups'
# "Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Single women's group (एकल महिला समुह)" -> 'community_groups'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Scout/Red cross (स्काउट/ रेड क्रस)' -> 'community_group'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Other (अन्य)' -> 'community_groups
#
# ### Completion'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/No (कुनैमा पनि छैन)' -> 'community_group_member'
# 'Community Groups/If other, please specify. (यदि अन्य समुह भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'community_group'
# "Community Groups/Women's participation in community/ ward/ municipal meeting and or decision making process (सामुदायिक/वडा/नगरपालिका  बैठक र निर्णय प्रक्रियामा घरको महिलाहरूको सहभागिता)" -> 'community_groups_women_participation'
# 'Citizenship Number of House Owner (नागरिकता नं)' -> 'citizenship_number'
# 'Phone number (फोन नं)' -> 'phone_number
#
# ### System:'
# 'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)' -> 'house_picture'
# 'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)_URL' -> 'photo_of_house'
# 'unique_identity' -> 'unique_identity'
# 'Your household unique ID is ${unique_identity}' -> 'household_id'
# '__version__' -> 'version
#
# ### System:'
# '_id' -> 'id'
# '_uuid' -> 'uuid'
# '_submission_time' -> 'submission_time'
# '_validation_status' -> 'validation_status'
# '_notes' -> 'notes'
# '_status' -> 'status'
# '_submitted_by' -> 'submitted_by
#
# ### System:'
# '_tags' -> 'tag'
# '_index' -> 'index
#
# ### System:'
# 'Unnamed: 341' -> 'unnamed_341'
# 'Unnamed: 342' -> 'unnamed_column_342'
# 'Unnamed: 343' -> 'no_label'
# 'Unnamed: 344' -> 'unnamed_344'
# 'परिवारको जग्गा in KATHA' -> 'household_land_katha
#
# ### System:'
# 'महिला सदस्यको नाममा भएको जग्गा in KATHA' -> 'female_household_land_in_katha'
# 'घरबाट खानेपानी सुविधाको दूरी in METER' -> 'food_and_water_facilities_distance'
# 'घरबाट स्वास्थ्य संस्थाको दुरी in METER' -> 'distance_from_health_facility_in_meters'
# '(घरबाट बजारको दुरी in METER' -> 'distance_from_home_to_market_in_meter
#
# ### System:
# In adhering to the structure you specified:'
# '(नजिकैको शौचालय र घरको दुरी in METER' -> 'nearest_toilet_distance_in_meter
#
# ### System:'
# '(Distance to safe Shelter in METER)' -> 'distance_to_safe_shelter'

# %% [markdown]
# WITHOUT USING LLM

# %%
import json
import re
import dspy

# ------------------------------
# DSPy Signature
# ------------------------------
class StandardizeHeader(dspy.Signature):
    """
    Automatically standardize a CSV header to a concise snake_case label.
    No predefined mapping is used.
    """

    original_header = dspy.InputField(
        desc="The original, potentially complex, CSV header string"
    )

    standardized_header = dspy.OutputField(
        desc="Automatically generated concise snake_case label."
    )

    @staticmethod
    def run(original_header: str) -> str:
        header = original_header.strip()

        # 1. Take last part after slash (most specific part)
        if '/' in header:
            header = header.split('/')[-1]

        # 2. Remove brackets and contents inside
        header = re.sub(r"[\(\)\[\]]", "", header)

        # 3. Remove non-ASCII characters (strip Nepali or other Unicode)
        header = re.sub(r"[^\x00-\x7F]", "", header)

        # 4. Replace punctuation with space
        header = re.sub(r"[^\w\s]", " ", header)

        # 5. Lowercase
        header = header.lower()

        # 6. Replace multiple spaces with single space
        header = re.sub(r"\s+", " ", header).strip()

        # 7. Map common abbreviations automatically
        header = header.replace("no", "number")  # House No → house_number

        # 8. Convert spaces to underscores
        header = header.replace(" ", "_")

        return header

# ------------------------------
# List of headers
# ------------------------------
headers = extracted_headers

# ------------------------------
# Apply standardization
# ------------------------------
standardized_mapping = {}
for h in headers:
    standardized_mapping[h] = StandardizeHeader.run(h)

# ------------------------------
# Save to JSON
# ------------------------------
output_file = "standardized_headers_auto3.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(standardized_mapping, f, indent=4, ensure_ascii=False)

# Print results
print("Standardizing headers...")
for original, standardized in standardized_mapping.items():
    print(f"'{original}' -> '{standardized}'")
# Out:
# Standardizing headers...
# '' -> ''
# 'start' -> 'start'
# 'end' -> 'end'
# 'today' -> 'today'
# 'username' -> 'username'
# 'simserial' -> 'simserial'
# 'subscriberid' -> 'subscriberid'
# 'deviceid' -> 'deviceid'
# 'phonenumber' -> 'phonenumber'
# 'General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)' -> 'name_of_municipality'
# 'General Questions/Municipality and Ward Details/Ward Number (वडा नं .)' -> 'ward_number'
# 'General Questions/Municipality and Ward Details/Ward Number (वडा नं )' -> 'ward_number'
# 'General Questions/Name of the Tole (सर्वेक्षण भैरहेको स्थानको नाम)' -> 'name_of_the_tole'
# 'General Questions/House No. (घर नं)' -> 'house_number'
# 'GPS Coordinates' -> 'gps_coordinates'
# 'General Questions/_GPS Coordinates_latitude' -> '_gps_coordinates_latitude'
# 'General Questions/_GPS Coordinates_longitude' -> '_gps_coordinates_longitude'
# 'General Questions/_GPS Coordinates_altitude' -> '_gps_coordinates_altitude'
# 'General Questions/_GPS Coordinates_precision' -> '_gps_coordinates_precision'
# 'General Questions/Do I have your consent to conduct this survey? (के यो सर्भे गर्नमा तपाइको सहमति छ?)' -> 'do_i_have_your_consent_to_conduct_this_survey'
# 'Basic Details of House Owner/Information on house owner/Name of the house owner (घरमुलीको नाम)' -> 'name_of_the_house_owner'
# 'Basic Details of House Owner/Information on house owner/Age of the house owner (घरमुलीको उमेर)' -> 'age_of_the_house_owner'
# 'Basic Details of House Owner/Information on house owner/Marital status of house owner (घरमुलीको वैवाहिक स्थिति)' -> 'marital_status_of_house_owner'
# 'Basic Details of House Owner/Information on house owner/Gender of house owner (घरमुलीको बिवरण)' -> 'gender_of_house_owner'
# 'Basic Details of House Owner/Information on house owner/Is the house owner differently abled? के घर मालिक फरक रूपमा सक्षम हुनहुन्छ?' -> 'is_the_house_owner_differently_abled'
# 'Basic Details of House Owner/Language and Ethnicity/Mother Tongue (मातृभाषा)' -> 'mother_tongue'
# 'Basic Details of House Owner/Language and Ethnicity/If other, specify here. (यदि अन्य मातृभाषा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_specify_here'
# 'Basic Details of House Owner/Language and Ethnicity/What is the ethnicity of the family? (परिवार कुन जातिमा पर्नुहुन्छ?)' -> 'what_is_the_ethnicity_of_the_family'
# 'Basic Details of House Owner/Language and Ethnicity/If other, please specify (यदि अन्य भए, यहाँ उल्लेख गर्नुहोस्)' -> 'if_other_please_specify'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_0_to_4_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_5_to_9_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_10_to_14_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_15_to_19_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_20_to_24_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_25_to_29_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_30_to_34_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_35_to_39_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_40_to_44_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_45_to_49_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_50_to_54_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला सद' -> 'number_of_female_members_of_the_age_group_55_to_59_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_60_to_64_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_65_to_69_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_70_to_74_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_75_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/total_female' -> 'total_female'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Female is ${total_female}' -> 'total_number_of_female_is_total_female'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_0_to_4_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_5_to_9_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_10_to_14_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_15_to_19_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_20_to_24_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_25_to_29_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_30_to_34_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_35_to_39_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_40_to_44_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_45_to_49_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_50_to_54_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने पुरुष  सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_55_to_59_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_60_to_64_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_65_to_69_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_70_to_74_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_75_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/total_male' -> 'total_male'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Male is ${total_male}' -> 'total_number_of_male_is_total_male'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या )' -> 'number_of_other_gender_members_of_the_age_group_0_to_4_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या' -> 'number_of_other_gender_members_of_the_age_group_5_to_9_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या) )' -> 'number_of_other_gender_members_of_the_age_group_10_to_14_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_15_to_19_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_20_to_24_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_25_to_29_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_30_to_34_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_35_to_39_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_40_to_44_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_45_to_49_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_50_to_54_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_55_to_59_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_60_to_64_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_65_to_69_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_70_to_74_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_75_years'
# 'Family Members Details/Total Number of Family Members and Age Group Details/total_other' -> 'total_other'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Others is ${total_other}' -> 'total_number_of_others_is_total_other'
# 'Family Members Details/Total Number of Family Members and Age Group Details/total_members' -> 'total_members'
# 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of family members is ${total_members}' -> 'total_number_of_family_members_is_total_members'
# 'Family Members Details/Identity Revealing Document/Do the house members have identity revealing documents? (के तपाइँ र तपाईको घरका सदस्यहरुसंग आफ्नो परिचय खुल्ने कागजात छ?)' -> 'do_the_house_members_have_identity_revealing_documents'
# 'Family Members Details/Identity Revealing Document/If few members do not have, specify the number. (यदि कसैको छैन भने, कति जनाको छैन यहाँ उल्लेख गर्नुहोस)' -> 'if_few_members_do_numbert_have_specify_the_number'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Pregnant and Lactating (गर्भवती तथा स्तनपान गराउने)' -> 'pregnant_and_lactating'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Widowed (विदुवा/विदुर)' -> ''
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Chronically ill (दिर्घकालिन रोग भएको)' -> 'chronically_ill'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)' -> 'people_with_disability'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Single Woman (एकल महिला)' -> 'single_woman'
# 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/None of the above (माथिका कुनै पनि छैन)' -> 'numberne_of_the_above'
# 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, specify the number. (यदि गर्भवती र स्तनपान गराउने हुनुहुन्छ भने, कति जना हुनुहुन्छ?' -> 'if_pregnant_and_lactating_specify_the_number'
# 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, are they differently abled? (यदि गर्भवती तथा स्तनपान गराउने भए, उहाहरु अपाङ्गता भएको वा फरक रुपमा सक्षम हुनुहुन्छ?)' -> 'if_pregnant_and_lactating_are_they_differently_abled'
# 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If yes, please write down the number of people with disability pregnant and lactating woman (यदि हुनुन्छ भने, अपाङ्गता भएको वा फरक रुपमा सक्षम कति जना हुनुन्छ?' -> 'if_yes_please_write_down_the_number_of_people_with_disability_pregnant_and_lactating_woman'
# 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Female (महिला)' -> 'female'
# 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Male (पुरुष)' -> 'male'
# 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Other (अन्य)' -> 'other'
# 'Family Members Details/Sensitive Population in the house/Widowed/How many members in the family members are widowed? (घरका कतिजना सदस्य विधवा/विदुर हुनुहुन्छ?)' -> ''
# 'Family Members Details/Sensitive Population in the house/Single woman/If single woman, how many members in the family are single woman? (यदि एकल महिला भएमा, कतिजना सदस्य एकल महिलामा पर्नुहुन्छ?)' -> 'if_single_woman_how_many_members_in_the_family_are_single_woman'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)' -> 'female'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)' -> 'male'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)' -> 'other'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, how many members in the family are people with disability? (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, घरमा कतिजना फरक रुपमा सक्षम हुनुहुन्छ?)' -> 'if_people_with_disability_how_many_members_in_the_family_are_people_with_disability'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Physical disabilities (शारीरिक असक्षमता)' -> 'physical_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Visual disabilities (दृष्टि असक्षमता)' -> 'visual_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing disabilities (श्रवण असक्षमता)' -> 'hearing_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing-Visual disabilities (श्रवण-दृश्य असक्षमता)' -> 'hearing_visual_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Speaking disabilities (बोल्ने असक्षमता)' -> 'speaking_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Mental disabilities (मानसिक असक्षमता)' -> 'mental_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Intellectual disabilities (बौद्दिक  असक्षमता)' -> 'intellectual_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Multiple disabilities (धेरै असक्षमताहरु)' -> 'multiple_disabilities'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Do the people with disability family member have identity revealing document provided by municipality? (के शारिरिक तथा मानसिक अपांगता भएको परिचय पत्र पालिका बाट प्राप्त गर्नुभएको छ?)' -> 'do_the_people_with_disability_family_member_have_identity_revealing_document_provided_by_municipality'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Red Card (रातो कार्ड)' -> 'red_card'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Blue Card (निलो कार्ड)' -> 'blue_card'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Yellow Card (पहेलो कार्ड)' -> 'yellow_card'
# 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/White Card (सेतो कार्ड)' -> 'white_card'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)' -> 'female'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)' -> 'male'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)' -> 'other'
# 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, how many members in the family are chronically ill? (यदि दिर्घकालिन रोग भएमा, घरका कतिजना सदस्यहरुलाइ दिर्घकालिन रोग छ?)' -> 'if_chronically_ill_how_many_members_in_the_family_are_chronically_ill'
# 'Family Members Details/Education Status/Literacy/Total literate female members in the house ( घरमा कुल साक्षर महिला सदस्यहरू)' -> 'total_literate_female_members_in_the_house'
# 'Family Members Details/Education Status/Literacy/Total literate male members in the house ( घरमा कुल साक्षर पुरुष सदस्यहरू)' -> 'total_literate_male_members_in_the_house'
# 'Family Members Details/Education Status/Literacy/Total literate other gender members in the house ( घरमा कुल साक्षर महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यहरू)' -> 'total_literate_other_gender_members_in_the_house'
# 'Family Members Details/Education Status/Literacy/total_literate' -> 'total_literate'
# 'Family Members Details/Education Status/Literacy/Total literate members of age between (15-60) years in the house (घरमा (१५-६०) वर्ष उमेर समुहका कुल साक्षर सदस्यहरू)' -> 'total_literate_members_of_age_between_15_60_years_in_the_house'
# 'Family Members Details/Education Status/Total Number of Literate Family Members is ${total_literate}' -> 'total_number_of_literate_family_members_is_total_literate'
# 'Family Members Details/Education Status/total_illiterate' -> 'total_illiterate'
# 'Family Members Details/Education Status/Total Number of Illiterate Family Members is ${total_illiterate}' -> 'total_number_of_illiterate_family_members_is_total_illiterate'
# 'Family Members Details/Education Status/Education Level/Total family members who are not eligible for schooling  (परिवारका कुल सदस्यहरू जो पढ्न योग्य नभएका)' -> 'total_family_members_who_are_numbert_eligible_for_schooling'
# 'Family Members Details/Education Status/Education Level/Total family members with other/non-formal education (अन्य/अनौपचारिक शिक्षा लिएका परिवारका कुल सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members whose education level is not known ( कुल परिवारका सदस्य जसको शिक्षा स्तर थाहा छैन)' -> 'total_family_members_whose_education_level_is_numbert_knumberwn'
# 'Family Members Details/Education Status/Education Level/Total family members at primary level of schooling (कक्षा ५ सम्म) विद्यालयको प्राथमिक तहमा (पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members at Lower Secondary level of schooling (विद्यालयको निम्न माध्यमिक तहमा  (कक्षा ८ सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members at Secondary level of schooling (विद्यालयको  माध्यमिक तहमा ((कक्षा ९ वा १० सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members at SLC or Equivalent level of schooling (SLC वा सो सरह स्तरमा पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members at Intermediate or Equivalent level of schooling (+२ पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members at Bachelor or Equivalent level of schooling (ब्याचलर वा सो सरह पढेका/पढ्ने परिवारका कुल सदस्यहरू)' -> ''
# 'Family Members Details/Education Status/Education Level/Total family members at Masters / Ph.D level of education (मास्टर्स/पी.एच.डी पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> ''
# 'Other Family Members Details/Are there any other families living in the same house? (तपाईको घरमा अन्य कुनै परिवार बस्नुहुन्छ?)' -> 'are_there_any_other_families_living_in_the_same_house'
# 'Other Family Members Details/If yes, how many female members are there? (यदि बस्नुहुन्छ भने, महिला सदस्य कतिजना हुनुहुन्छ?)' -> 'if_yes_how_many_female_members_are_there'
# 'Other Family Members Details/How many male members are there? (यदि बस्नुहुन्छ भने, पुरुष सदस्य कतिजना हुनुहुन्छ?)' -> 'how_many_male_members_are_there'
# 'Other Family Members Details/How many members of other gender are there ? (यदि बस्नुहुन्छ भने, अन्य महिला वा पुरुष भनि पहिचान नगर्ने सदस्य कतिजना हुनुहुन्छ?)' -> 'how_many_members_of_other_gender_are_there'
# 'Economic Condition of the House Owner Family/Major Occupation/What is the primary occupation of your family? (तपाईको घरको प्रमुख पेशा कुन हो?)' -> 'what_is_the_primary_occupation_of_your_family'
# 'Economic Condition of the House Owner Family/Major Occupation/If other, please specify (यदि अन्य मुख्य पेशा भए, यहाँ उल्लेख गर्नुहोस्)' -> 'if_other_please_specify'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Agriculture and Livestock (कृषि तथा पशुपालन)' -> 'agriculture_and_livestock'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/On-farm Daily Wage Worker (कृषि क्षेत्रमा दैनिक ज्याला मजदुर)' -> 'on_farm_daily_wage_worker'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Off-farm Daily Wage Worker (गैर कृषि क्षेत्रमा दैनिक ज्याला मजदुर)' -> 'off_farm_daily_wage_worker'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Business (व्यापार तथा व्यवसाय)' -> 'business'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Government Service (सरकारी सेवा)' -> 'government_service'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Private Job (निजी सेवा)' -> 'private_job'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Foreign Employment/Remittance (वैदेशिक रोजगार)' -> 'remittance'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Other (अन्य)' -> 'other'
# 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/No supporting occupation (कुनै सहायक पेशा छैन)' -> 'number_supporting_occupation'
# 'Economic Condition of the House Owner Family/Supporting Occupation/If other, please specify (यदि अन्य सहायक पेशा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_please_specify'
# 'Economic Condition of the House Owner Family/Supporting Occupation/Number of unemployed members in the household (घरमा कतिजना वेरोजगार हुनुहुन्छ?)' -> 'number_of_unemployed_members_in_the_household'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Do you or your family members own land? (के तपाइँ र तपाइको परिवारको नाममा जग्गा-जमिन छ?)' -> 'do_you_or_your_family_members_own_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/How much land do you or your family hold? (तपाइँ र तपाईको परिवारको जग्गा कति छ?)' -> 'how_much_land_do_you_or_your_family_hold'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)' -> 'please_choose_the_unit_of_measurement_of_land_area'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other type, please specify the type of land (यदि अन्य भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_please_specify_the_type_of_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)' -> ''
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)' -> ''
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Forested Area (वन क्षेत्र)' -> 'forested_area'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Open Space (खुल्ला स्थान)' -> 'open_space'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Commercial Purpose (व्यापारिक क्षेत्र)' -> 'commercial_purpose'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)' -> 'barren_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Other (अन्य)' -> 'other'
# 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other land type, please specify the type of land (यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_land_type_please_specify_the_type_of_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Do the female members of the house own the land? (घरको महिला सदस्यको नाममा जग्गा-जमिन छ?)' -> 'do_the_female_members_of_the_house_own_the_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Total land held by female of the house (घरको महिला सदस्यको नाममा भएको जग्गा कति छ?)' -> 'total_land_held_by_female_of_the_house'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)' -> 'please_choose_the_unit_of_measurement_of_land_area'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type that helds by female, please specify the type of land (महिला सदस्यले यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_land_type_that_helds_by_female_please_specify_the_type_of_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)' -> ''
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)' -> ''
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Forested Area (वन क्षेत्र)' -> 'forested_area'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Open Space (खुल्ला स्थान)' -> 'open_space'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Commercial Purpose (व्यापारिक क्षेत्र)' -> 'commercial_purpose'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)' -> 'barren_land'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Other (अन्य)' -> 'other'
# 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type, specify here. (यदि अन्य भू-उपयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_land_type_specify_here'
# 'Economic Condition of the House Owner Family/Income and Expenditure/Annual income of the family (वार्षिक आम्दानी)' -> 'annual_income_of_the_family'
# 'Economic Condition of the House Owner Family/Income and Expenditure/Monthly Expenditure of the house  (घरको मासिक खर्च)' -> 'monthly_expenditure_of_the_house'
# 'Economic Condition of the House Owner Family/Income and Expenditure/Yearly saving of the house  (घरको वार्षिक बचत)' -> 'yearly_saving_of_the_house'
# 'Economic Condition of the House Owner Family/Saving, Credit and Loan/Have you taken loan from the financial institutions? (के तपाइले कुनै वित्तीय संस्था बाट ऋण लिनुभएको छ?)' -> 'have_you_taken_loan_from_the_financial_institutions'
# 'Economic Condition of the House Owner Family/Saving, Credit and Loan/Covered by subsidized loan targeted for women/marginalized group (घरको  महिला/सीमान्तकृत समूहका लागि लक्षित सहुलियतपूर्ण ऋण पाएको छ?)' -> ''
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Is any family member receiving reservations, allowances and special privilege systems? (के तपाइको घरको कुनै सदस्यले कुनै आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)' -> 'is_any_family_member_receiving_reservations_allowances_and_special_privilege_systems'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen (ज्येष्ठ नागरिक)' -> 'senior_citizen'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Dalit (ज्येष्ठ नागरिक दलित)' -> 'senior_citizen_dalit'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Single Women (ज्येष्ठ नागरिक एकल महिला)' -> 'senior_citizen_single_women'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Widowed (विधवा/ एकल महिला)' -> ''
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)' -> 'people_with_disability'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Dalit Child Allowance (दलित बाल बालिका)' -> 'dalit_child_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Pension (पेन्सन)' -> 'pension'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Others (अन्य)' -> 'others'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If other type of privilege system, please specify (यदि अन्य किसिमको सुविधाहरु भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_of_privilege_system_please_specify'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen allowance (वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen dalit allowance (दलित वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_dalit_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen single woman allowance (महिला वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_single_woman_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  widowed allowance (विधवा भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_widowed_allowance'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  allowance for differently abled (अपाङ्गता भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_allowance_for_differently_abled'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  allowance for dalit child (दलित बाल-बालिका  भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_allowance_for_dalit_child'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving pension (पेन्सन पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_pension'
# 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving other type of allowance (अन्य किसिमका भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_other_type_of_allowance'
# 'Economic Condition of the House Owner Family/Insurance Details/Have you or your family member taken any type of insurance? (के तपाइ तथा तपाँईको परिवारको कुनै सदस्यहरूले विमा गर्नुभएको छ?)' -> 'have_you_or_your_family_member_taken_any_type_of_insurance'
# 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Life Insurance (जीवन विमा)' -> 'life_insurance'
# 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Animal Insurance (पशु विमा)' -> 'animal_insurance'
# 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Crop Insurance (बाली विमा)' -> 'crop_insurance'
# 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Health Insurance (स्वास्थ्य विमा)' -> 'health_insurance'
# 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Other (अन्य)' -> 'other'
# 'Economic Condition of the House Owner Family/Insurance Details/If other type of insurance, please specify (यदि अन्य विमा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_of_insurance_please_specify'
# 'Economic Condition of the House Owner Family/Occupational and Livelihood/Do you or your family fall in the Occupational and livelihood groups mentioned below? ( तल उल्लेख  पेशागत र जीविकोपार्जन समूहमा तपाइँ र तपाइको परिवार पर्नुहुन्छ?)' -> 'do_you_or_your_family_fall_in_the_occupational_and_livelihood_groups_mentioned_below'
# 'Economic Condition of the House Owner Family/Occupational and Livelihood/If other occupational and livelihood groups, please specify (यदि अन्य पेशागत र जीविकोपार्जन समुह भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_occupational_and_livelihood_groups_please_specify'
# 'Economic Condition of the House Owner Family/Communication/Do you have communication device at your house? (के तपाइँको घरमा संचार साधन उपलब्ध छ?)' -> 'do_you_have_communication_device_at_your_house'
# 'Economic Condition of the House Owner Family/Communication/If yes, what type of communication devices are at your house? (यदि छ भने, तल उल्लेख मध्ये कुन संचार माध्यम उपलब्ध छन्?)/Radio (रेडियो)' -> 'radio'
# ...
# 'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Forest (वन)' -> 'forest'
# 'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Water Resources (जलस्रोत)' -> 'water_resources'
# 'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Other natural resources (अन्य प्राकृतिक स्रोत)' -> 'other_natural_resources'
# 'Access to Various Resources/Access to other resources/Which type of natural resources do you have access to? (तल उल्लेख मध्ये कुन-कुन प्राकृतिक स्रोतहरुको पहुँच छ?)/Do not have access (कुनै पनि छैन)' -> 'do_numbert_have_access'
# 'Access to Various Resources/Access to other resources/If other natural resources, please specify (यदि अन्य प्राकृतिक स्रोत भए, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_natural_resources_please_specify'
# 'Details on the House/Structure Built and Permit/Age of the house (In years) (घर निर्माण भएको कति वर्ष भयो?)' -> 'age_of_the_house_in_years'
# 'Details on the House/Structure Built and Permit/Number of storey of the house (घरको तल्ला)' -> 'number_of_storey_of_the_house'
# 'Details on the House/Structure Built and Permit/Is the building designed following building code? (के तपाइले घर बनाउदा भवन निर्माण संहिता पालना गरेर निर्माण गर्नुभएको हो?)' -> 'is_the_building_designed_following_building_code'
# 'Details on the House/Structure Built and Permit/Have you received a building permit from the municipality? ( नगरपालिकाबाट निर्माण स्वीकृति लिनुभएको छ?)' -> 'have_you_received_a_building_permit_from_the_municipality'
# 'Details on the House/Construction Materials/Type of foundation of the building (तल उल्लेख मध्ये तपाईको घरको जगको निर्माण सामाग्री के-के हुन्)' -> 'type_of_foundation_of_the_building'
# 'Details on the House/Construction Materials/If other type of foundation materials, please specify. (यदि अन्य प्रकारको निर्माण सामग्री भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_of_foundation_materials_please_specify'
# 'Details on the House/Construction Materials/Please mention the building type of your house (तपाइको घर तल उल्लेख मध्ये कुन किसिमको हो?)' -> 'please_mention_the_building_type_of_your_house'
# 'Details on the House/Construction Materials/If other type of building type, please specify. (यदि अन्य प्रकारको भवन भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_of_building_type_please_specify'
# 'Details on the House/Construction Materials/What materials are used for the construction of Wall of your house? (तपाइको घरको भित्ता के ले बनेको छ?)' -> 'what_materials_are_used_for_the_construction_of_wall_of_your_house'
# 'Details on the House/Construction Materials/If other wall type, please specify (यदि अन्य सामग्रीले बनेको भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_wall_type_please_specify'
# 'Details on the House/Construction Materials/What materials are used for the construction of Roof of your house? (तपाइको घरको छाना केले निर्माण गरिएको छ?)' -> 'what_materials_are_used_for_the_construction_of_roof_of_your_house'
# 'Details on the House/Construction Materials/If other materials of roof, please specify. (यदि अन्य निर्माण सामग्रीले छाना बनेको भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_materials_of_roof_please_specify'
# 'Details on the House/Construction Materials/Is the roof easily accessible in case of any emergency? (के तपाइको घरको छतमा सजिलै जान र बस्न मिल्छ?)' -> 'is_the_roof_easily_accessible_in_case_of_any_emergency'
# 'Details on the House/Current Condition/What is the current condition of your house? (तपाइको घरको अहिलेको अवस्था कस्तो छ?)' -> 'what_is_the_current_condition_of_your_house'
# 'Details on the House/Current Condition/How is the ground surface of the area in which your house has been built? (तपाईको घर निर्माण भएको जमिनको सतह कस्तो छ?)' -> 'how_is_the_ground_surface_of_the_area_in_which_your_house_has_been_built'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Raised Plinth and above flood level (उठाएको प्लिन्थ-बाढीको सतह भन्दा माथि)' -> 'raised_plinth_and_above_flood_level'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Strong wall (मजबुत पर्खाल)' -> 'strong_wall'
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Proper drainage (उचित ढल/जल निकासी)' -> ''
# 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/None of the above (माथिको कुनै पनि होइन)' -> 'numberne_of_the_above'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years, how many times have you experienced flooding events? (विगत ३० वर्षमा तपाइले कति पटक बाढीका घटनाहरुको अनुभव गर्नुभएको छ?)' -> 'in_the_past_30_years_how_many_times_have_you_experienced_flooding_events'
# 'Hazard and Disaster/Historical Damage and Loss/In the past flooding events, what is the maximum depth of flood occurrence surrounding the household? विगतको बाढी घटनामा, घर वरिपरि बाढीको अधिकतम गहिराई कति थियो ?' -> 'in_the_past_flooding_events_what_is_the_maximum_depth_of_flood_occurrence_surrounding_the_household'
# 'Hazard and Disaster/Historical Damage and Loss/Select the unit of flood depth measurement. (बाढीको गहिराई नाप्ने इकाइ चयन गर्नुहोस्।)' -> 'select_the_unit_of_flood_depth_measurement'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Death of  household members (परिवारको सदस्यको मृत्यु भएको)' -> 'death_of_household_members'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Missing household members (परिवारको सदस्य हराएको)' -> 'missing_household_members'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Injured household members (परिवारको सदस्य घाइते हुनुभएको)' -> 'injured_household_members'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/People displaced (विस्थापित)' -> 'people_displaced'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to house (घरमा क्षति भएको)' -> 'damage_to_house'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Land affected (जमिन क्षति भएको)' -> 'land_affected'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Livestock affected (पशु क्षति भएको)' -> 'livestock_affected'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Farmland affected (खेति जमिनमा क्षति)' -> 'farmland_affected'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to stored food stock (भण्डारण गरिएको खाद्यान्न क्षति)' -> 'damage_to_stored_food_stock'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Non-Structural Damage (गैर-संरचनात्मक क्षति)' -> 'numbern_structural_damage'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Loss of other livelihood options ( such as loss of job, business, other than agriculture)' -> 'loss_of_other_livelihood_options_such_as_loss_of_job_business_other_than_agriculture'
# 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/No any damage (कुनै पनि क्षति नभएको)' -> 'number_any_damage'
# 'Hazard and Disaster/Historical Damage and Loss/Number of people death (मृत्यु हुनेको संख्या)' -> 'number_of_people_death'
# 'Hazard and Disaster/Historical Damage and Loss/Number of missing family members (हराएका परिवारको सदस्यको संख्या)' -> 'number_of_missing_family_members'
# 'Hazard and Disaster/Historical Damage and Loss/Number of injured family members (घाइतेको संख्या)' -> 'number_of_injured_family_members'
# 'Hazard and Disaster/Historical Damage and Loss/Number of people displaced (विस्थापित संख्या)' -> 'number_of_people_displaced'
# 'Hazard and Disaster/Historical Damage and Loss/Total area of farmland affected (कुल खेति जमिन क्षति)' -> 'total_area_of_farmland_affected'
# 'Hazard and Disaster/Historical Damage and Loss/Unit of measurement of affected farmland area (प्रभावित खेति जमिन क्षेत्रको मापनको इकाइ)' -> 'unit_of_measurement_of_affected_farmland_area'
# 'Hazard and Disaster/Historical Damage and Loss/Estimated agricultural loss (कुल कृषि क्षति)' -> 'estimated_agricultural_loss'
# 'Hazard and Disaster/Historical Damage and Loss/Type of damage to the house (घरको क्षतिको प्रकार)' -> 'type_of_damage_to_the_house'
# 'Hazard and Disaster/Historical Damage and Loss/Total livestock loss (कुल पशु क्षतिको संख्या)' -> 'total_livestock_loss'
# 'Hazard and Disaster/Historical Damage and Loss/Estimated livestock loss NPR (कुल पशु क्षति)' -> 'estimated_livestock_loss_npr'
# 'Hazard and Disaster/Historical Damage and Loss/Total loss of stored food KG (भण्डारण गरिएको खाद्यान्न क्षति)' -> 'total_loss_of_stored_food_kg'
# 'Hazard and Disaster/Historical Damage and Loss/Total Estimated loss NPR (कुल अनुमानित क्षति)' -> 'total_estimated_loss_npr'
# 'Hazard and Disaster/Historical Damage and Loss/If loss of other livelihood options, please specify. अन्य जीविकोपार्जनका विकल्पहरू गुमाएमा, कृपया यहाँ उल्लेख गर्नुहोस्।' -> 'if_loss_of_other_livelihood_options_please_specify'
# 'Hazard and Disaster/Knowledge and Training in Disaster/Have any family members received training on disaster? (के तपाइँ वा तपाईको परिवारको सदस्यले विपद सम्बन्धी तालिम लिनुभएको छ?)' -> 'have_any_family_members_received_training_on_disaster'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/First Aid (प्राथमिक उपचार)' -> 'first_aid'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Search and rescue (खोज तथा उद्दार)' -> 'search_and_rescue'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Simulation and drill exercise (सिमुलेशन र ड्रिल)' -> 'simulation_and_drill_exercise'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Other Disaster related training (विपद सम्बन्धी अन्य तालिम)' -> 'other_disaster_related_training'
# 'Hazard and Disaster/Knowledge and Training in Disaster/If other disaster related trainings received, please specify what type of trainings. (यदि विपद सम्बन्धी अन्य तालिम भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_disaster_related_trainings_received_please_specify_what_type_of_trainings'
# 'Hazard and Disaster/Aftermath of Past Disaster/Access to social assistance in the aftermath of past disaster (विगतको प्रकोप पछि सामाजिक सहायता प्राप्त भएको थियो?)' -> 'access_to_social_assistance_in_the_aftermath_of_past_disaster'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/DRRM committee of ward/municipality (पालिका वा वडाको विपद सम्बन्धी समितिमा)' -> 'municipality'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Women group (महिला समुह)' -> 'women_group'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Youth group (युवा समुह)' -> 'youth_group'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Child group (बाल समुह)' -> 'child_group'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Single women's group (एकल महिला समुह)' -> 'single_women_s_group'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Scout/Red cross (स्काउट/ रेड क्रस)' -> ''
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Other (अन्य)' -> 'other'
# 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/No (कुनैमा पनि छैन)' -> 'number'
# 'Community Groups/If other, please specify. (यदि अन्य समुह भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_please_specify'
# 'Community Groups/Women's participation in community/ ward/ municipal meeting and or decision making process (सामुदायिक/वडा/नगरपालिका  बैठक र निर्णय प्रक्रियामा घरको महिलाहरूको सहभागिता)' -> ''
# 'Citizenship Number of House Owner (नागरिकता नं)' -> 'citizenship_number_of_house_owner'
# 'Phone number (फोन नं)' -> 'phone_number'
# 'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)' -> 'please_take_the_picture_of_the_house'
# 'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)_URL' -> 'please_take_the_picture_of_the_house__url'
# 'unique_identity' -> 'unique_identity'
# 'Your household unique ID is ${unique_identity}' -> 'your_household_unique_id_is_unique_identity'
# '__version__' -> '__version__'
# '_id' -> '_id'
# '_uuid' -> '_uuid'
# '_submission_time' -> '_submission_time'
# '_validation_status' -> '_validation_status'
# '_notes' -> '_numbertes'
# '_status' -> '_status'
# '_submitted_by' -> '_submitted_by'
# '_tags' -> '_tags'
# '_index' -> '_index'
# 'Unnamed: 341' -> 'unnamed_341'
# 'Unnamed: 342' -> 'unnamed_342'
# 'Unnamed: 343' -> 'unnamed_343'
# 'Unnamed: 344' -> 'unnamed_344'
# 'परिवारको जग्गा in KATHA' -> 'in_katha'
# 'महिला सदस्यको नाममा भएको जग्गा in KATHA' -> 'in_katha'
# 'घरबाट खानेपानी सुविधाको दूरी in METER' -> 'in_meter'
# 'घरबाट स्वास्थ्य संस्थाको दुरी in METER' -> 'in_meter'
# '(घरबाट बजारको दुरी in METER' -> 'in_meter'
# '(नजिकैको शौचालय र घरको दुरी in METER' -> 'in_meter'
# '(Distance to safe Shelter in METER)' -> 'distance_to_safe_shelter_in_meter'

# %% [markdown]
# ### Header Standardization WITHOUT LLM
#
# This section demonstrates how to standardize headers using a purely regex-based approach, without involving any Large Language Model. The `StandardizeHeader` class, defined earlier, uses a series of regular expressions to clean and convert headers into a snake_case format.

# %%
import json
import re

# Re-define the StandardizeHeader class to ensure it's available in this context
class StandardizeHeader(): # Note: Removed dspy.Signature as it's not needed for this standalone run
    """
    Automatically standardize a CSV header to a concise snake_case label.
    Fully automated: no clusters, no mappings.
    """

    # The original_header and standardized_header fields from dspy.Signature are not directly used in the static method below
    # but are kept as comments for context if this were part of a dspy pipeline.
    # original_header = dspy.InputField(desc="The original, potentially complex, CSV header string")
    # standardized_header = dspy.OutputField(desc="Automatically generated concise snake_case label.")

    @staticmethod
    def run(original_header: str) -> str:
        header = original_header.strip()

        if '/' in header:
            header = header.split('/')[-1]

        header = re.sub(r"[()[\]]", "", header)
        header = re.sub(r"[^\x00-\x7F]", "", header)
        header = re.sub(r"[^\w\s]", " ", header)
        header = header.lower()
        header = re.sub(r"\s+", " ", header).strip()
        header = header.replace("no", "number")
        header = header.replace(" ", "_")
        header = header.strip("_")

        return header

# Assuming extracted_headers is already defined from previous cells
# If not, you would need to load it here, e.g.:
# with open('extracted_headers.json', 'r') as f:
#    extracted_headers = json.load(f)

standardized_mapping_regex_only = {}
for h in extracted_headers:
    standardized = StandardizeHeader.run(h)
    standardized_mapping_regex_only[h] = standardized

output_file_regex = "standardized_headers_regex_only.json"

with open(output_file_regex, "w", encoding="utf-8") as f:
    json.dump(standardized_mapping_regex_only, f, indent=4, ensure_ascii=False)

print(f"✅ Saved regex-only standardized headers to {output_file_regex}")

print("\nExample regex-only standardized headers:")
for original, standardized in list(standardized_mapping_regex_only.items())[:10]: # Print first 10 examples
    print(f"'{original}' -> '{standardized}'")

# %%
import re
import dspy
# ------------------------------
# 1. Regex-based Standardizer
# ------------------------------
class StandardizeHeader(dspy.Signature):
    """
    Automatically standardize a CSV header to a concise snake_case label.
    Fully automated: no clusters, no mappings.
    """

    original_header = dspy.InputField(desc="The original, potentially complex, CSV header string")
    standardized_header = dspy.OutputField(desc="Automatically generated concise snake_case label.")

    @staticmethod
    def run(original_header: str) -> str:
        header = original_header.strip()

        if '/' in header:
            header = header.split('/')[-1]

        header = re.sub(r"[()[\]]", "", header)
        header = re.sub(r"[^\x00-\x7F]", "", header)
        header = re.sub(r"[^\w\s]", " ", header)
        header = header.lower()
        header = re.sub(r"\s+", " ", header).strip()
        header = header.replace("no", "number")
        header = header.replace(" ", "_")
        header = header.strip("_")

        return header

# %%
# ------------------------------
# 2. DSPy Semantic Cleaner
# ------------------------------
class CleanHeaderToLabel(dspy.Signature):
    """
    You are an expert in cleaning and standardizing CSV column headers from humanitarian/nepali surveys.
    Convert messy, nested, multilingual headers into short, clean, snake_case English labels.
    Remove redundancy, keep only meaningful parts, prefer clarity and brevity.
    Never include numbers unless they are part of the meaning (e.g., age_0_5).
    Always use snake_case. Never use camelCase or spaces.
    """

    raw_header: str = dspy.InputField(desc="Original messy CSV header, may contain slashes, parentheses, Nepali text, repetition")
    clean_label: str = dspy.OutputField(desc="Clean snake_case English label, e.g. widowed_female, latitude, household_head_name")

# %%
import re
import dspy
from dspy.teleprompt import BootstrapFewShot
import json

# ------------------------------
# 1. Regex-based Standardizer
# ------------------------------
class StandardizeHeader(dspy.Signature):
    """
    Automatically standardize a CSV header to a concise snake_case label.
    Fully automated: no clusters, no mappings.
    """

    original_header = dspy.InputField(desc="The original, potentially complex, CSV header string")
    standardized_header = dspy.OutputField(desc="Automatically generated concise snake_case label.")

    @staticmethod
    def run(original_header: str) -> str:
        header = original_header.strip()

        if '/' in header:
            header = header.split('/')[-1]

        header = re.sub(r"[()[\]]", "", header)
        header = re.sub(r"[^\x00-\x7F]", "", header)
        header = re.sub(r"[^\w\s]", " ", header)
        header = header.lower()
        header = re.sub(r"\s+", " ", header).strip()
        header = header.replace("no", "number")
        header = header.replace(" ", "_")
        header = header.strip("_")

        return header

# ------------------------------
# 2. DSPy Semantic Cleaner
# ------------------------------
class CleanHeaderToLabel(dspy.Signature):
    """
    You are an expert in cleaning and standardizing CSV column headers from humanitarian/nepali surveys.
    Convert messy, nested, multilingual headers into short, clean, snake_case English labels.
    Remove redundancy, keep only meaningful parts, prefer clarity and brevity.
    Never include numbers unless they are part of the meaning (e.g., age_0_5).
    Always use snake_case. Never use camelCase or spaces.
    """

    raw_header: str = dspy.InputField(desc="Original messy CSV header, may contain slashes, parentheses, Nepali text, repetition")
    clean_label: str = dspy.OutputField(desc="Clean snake_case English label, e.g. widowed_female, latitude, household_head_name")

# ------------------------------
# 3. Module to Process Headers
# ------------------------------
class HeaderStandardizer(dspy.Module):
    def __init__(self, headers, examples=None):
        super().__init__()
        self.headers = headers
        self.examples = examples
        self.mapping_regex = {}
        self.mapping_clean = {}
        self.compiled_cleaner = None

    def run(self):
        print("Standardizing headers (regex + DSPy)...")

        # Ensure DSPy LM is configured
        if dspy.settings.lm is None:
            print("DSPy LM not configured. Attempting to re-configure using global 'llm' variable.")
            try:
                global llm
                if 'llm' in globals():
                    dspy.configure(lm=llm)
                    print("DSPy configured with global 'llm'.")
                else:
                    raise NameError("The 'llm' variable is not defined. Please run cell 9ZtbP4vmdCKA first.")
            except Exception as e:
                raise RuntimeError(f"Failed to configure DSPy LM: {e}. Please ensure cell 9ZtbP4vmdCKA is run.")

        # Regex-based
        for h in self.headers:
            standardized = StandardizeHeader.run(h)
            self.mapping_regex[h] = standardized
            print(f"[Regex] '{h}' -> '{standardized}'")

        # DSPy semantic cleaner with few-shot compilation
        if self.examples:
            print("Compiling DSPy semantic cleaner with few-shot examples...")
            teleprompter = BootstrapFewShot(metric=None) # No specific metric needed for simple example application
            self.compiled_cleaner = teleprompter.compile(dspy.ChainOfThought(CleanHeaderToLabel), trainset=self.examples)
            cleaner_to_use = self.compiled_cleaner
            print("DSPy semantic cleaner compiled with few-shot examples.")
        else:
            cleaner_to_use = dspy.ChainOfThought(CleanHeaderToLabel)
            print("DSPy semantic cleaner running without few-shot examples.")

        print("\nGenerating clean labels with DSPy:")
        for h in self.headers:
            result = cleaner_to_use(raw_header=h.strip().strip("'"))
            self.mapping_clean[h] = result.clean_label
            print(f"[DSPy]  '{h}' -> '{result.clean_label}'")

        return self.mapping_regex, self.mapping_clean

    def save_json(self, filename="standardized_headers.json"):
        combined = {
            "regex_based": self.mapping_regex,
            "semantic_cleaned": self.mapping_clean,
        }
        with open(filename, "w", encoding="utf-8") as f:
            json.dump(combined, f, indent=4, ensure_ascii=False)
        print(f"✅ Saved standardized headers to {filename}")

# %%
# ------------------------------
# 4. Few-shot Examples (for reference only)
# ------------------------------
examples = [
    dspy.Example(
        raw_header="General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)",
        clean_label="municipality_name"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="General Questions/_GPS Coordinates_latitude",
        clean_label="latitude"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Family Members widowed Details/.../Female (महिला)",
        clean_label="widowed_female"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Household Members/Number of household members/People living in this house for more than 6 months",
        clean_label="household_size"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Livelihood/Income Sources/Main Source of Income (आयको मुख्य स्रोत)",
        clean_label="main_income_source"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="Disability/.../Seeing (even with glasses)",
        clean_label="disability_vision"
    ).with_inputs("raw_header"),

    dspy.Example(
        raw_header="note_001_start_time",
        clean_label="survey_start_time"
    ).with_inputs("raw_header"),
]

# %%
# ------------------------------
# 5. Run Pipeline
# ------------------------------
if __name__ == "__main__":
    headers = extracted_headers  # your messy headers list

    # Assuming 'examples' variable is defined in cell 'vztx-5RpV8Ni'.
    if 'examples' not in globals():
        print("Warning: 'examples' list not found. Running HeaderStandardizer without few-shot examples.")
        module = HeaderStandardizer(headers=headers)
    else:
        module = HeaderStandardizer(headers=headers, examples=examples)

    regex_map, clean_map = module.run()
    module.save_json("standardized_headers_final5.json")
# Out:
# Standardizing headers (regex + DSPy)...
# [Regex] '' -> ''
# [Regex] 'start' -> 'start'
# [Regex] 'end' -> 'end'
# [Regex] 'today' -> 'today'
# [Regex] 'username' -> 'username'
# [Regex] 'simserial' -> 'simserial'
# [Regex] 'subscriberid' -> 'subscriberid'
# [Regex] 'deviceid' -> 'deviceid'
# [Regex] 'phonenumber' -> 'phonenumber'
# [Regex] 'General Questions/Municipality and Ward Details/Name of Municipality (नगरपालिकाको नाम)' -> 'name_of_municipality'
# [Regex] 'General Questions/Municipality and Ward Details/Ward Number (वडा नं .)' -> 'ward_number'
# [Regex] 'General Questions/Municipality and Ward Details/Ward Number (वडा नं )' -> 'ward_number'
# [Regex] 'General Questions/Name of the Tole (सर्वेक्षण भैरहेको स्थानको नाम)' -> 'name_of_the_tole'
# [Regex] 'General Questions/House No. (घर नं)' -> 'house_number'
# [Regex] 'GPS Coordinates' -> 'gps_coordinates'
# [Regex] 'General Questions/_GPS Coordinates_latitude' -> 'gps_coordinates_latitude'
# [Regex] 'General Questions/_GPS Coordinates_longitude' -> 'gps_coordinates_longitude'
# [Regex] 'General Questions/_GPS Coordinates_altitude' -> 'gps_coordinates_altitude'
# [Regex] 'General Questions/_GPS Coordinates_precision' -> 'gps_coordinates_precision'
# [Regex] 'General Questions/Do I have your consent to conduct this survey? (के यो सर्भे गर्नमा तपाइको सहमति छ?)' -> 'do_i_have_your_consent_to_conduct_this_survey'
# [Regex] 'Basic Details of House Owner/Information on house owner/Name of the house owner (घरमुलीको नाम)' -> 'name_of_the_house_owner'
# [Regex] 'Basic Details of House Owner/Information on house owner/Age of the house owner (घरमुलीको उमेर)' -> 'age_of_the_house_owner'
# [Regex] 'Basic Details of House Owner/Information on house owner/Marital status of house owner (घरमुलीको वैवाहिक स्थिति)' -> 'marital_status_of_house_owner'
# [Regex] 'Basic Details of House Owner/Information on house owner/Gender of house owner (घरमुलीको बिवरण)' -> 'gender_of_house_owner'
# [Regex] 'Basic Details of House Owner/Information on house owner/Is the house owner differently abled? के घर मालिक फरक रूपमा सक्षम हुनहुन्छ?' -> 'is_the_house_owner_differently_abled'
# [Regex] 'Basic Details of House Owner/Language and Ethnicity/Mother Tongue (मातृभाषा)' -> 'mother_tongue'
# [Regex] 'Basic Details of House Owner/Language and Ethnicity/If other, specify here. (यदि अन्य मातृभाषा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_specify_here'
# [Regex] 'Basic Details of House Owner/Language and Ethnicity/What is the ethnicity of the family? (परिवार कुन जातिमा पर्नुहुन्छ?)' -> 'what_is_the_ethnicity_of_the_family'
# [Regex] 'Basic Details of House Owner/Language and Ethnicity/If other, please specify (यदि अन्य भए, यहाँ उल्लेख गर्नुहोस्)' -> 'if_other_please_specify'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_0_to_4_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_5_to_9_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_10_to_14_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_15_to_19_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_20_to_24_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_25_to_29_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_30_to_34_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_35_to_39_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_40_to_44_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_45_to_49_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_50_to_54_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला सद' -> 'number_of_female_members_of_the_age_group_55_to_59_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_60_to_64_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_65_to_69_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_group_70_to_74_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age group- Female/No. of female members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला सदस्यहरुको संख्या)' -> 'number_of_female_members_of_the_age_75_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/total_female' -> 'total_female'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Female is ${total_female}' -> 'total_number_of_female_is_total_female'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_0_to_4_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_5_to_9_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_10_to_14_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_15_to_19_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_20_to_24_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_25_to_29_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_30_to_34_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_35_to_39_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_40_to_44_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_45_to_49_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_50_to_54_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने पुरुष  सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_55_to_59_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_60_to_64_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_65_to_69_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_group_70_to_74_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/No. of male members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने पुरुष सदस्यहरुको संख्या)' -> 'number_of_male_members_of_the_age_75_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Male/total_male' -> 'total_male'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Male is ${total_male}' -> 'total_number_of_male_is_total_male'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 0 to 4 years. ( ० देखि ४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या )' -> 'number_of_other_gender_members_of_the_age_group_0_to_4_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 5 to 9 years. ( ५ देखि ९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या' -> 'number_of_other_gender_members_of_the_age_group_5_to_9_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 10 to 14 years. ( १० देखि १४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या) )' -> 'number_of_other_gender_members_of_the_age_group_10_to_14_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 15 to 19 years. ( १५ देखि १९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_15_to_19_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 20 to 24 years. ( २० देखि २४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_20_to_24_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 25 to 29 years. ( २५ देखि २९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_25_to_29_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 30 to 34 years. ( ३० देखि ३४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_30_to_34_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 35 to 39 years. ( ३५ देखि ३९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_35_to_39_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 40 to 44 years. ( ४० देखि ४४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_40_to_44_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 45 to 49 years. ( ४५ देखि ४९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_45_to_49_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 50 to 54 years. ( ५० देखि ५४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_50_to_54_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 55 to 59 years. ( ५५ देखि ५९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_55_to_59_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 60 to 64 years. ( ६० देखि ६४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_60_to_64_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 65 to 69 years. ( ६५ देखि ६९ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_65_to_69_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age group 70 to 74 years. ( ७०  देखि ७४ वर्षको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_group_70_to_74_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Age Group- Others/No. of other gender members of the age 75+ years. ( ७५ वर्ष भन्दा माथिको उमेर समूहमा पर्ने महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यको संख्या)' -> 'number_of_other_gender_members_of_the_age_75_years'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/total_other' -> 'total_other'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of Others is ${total_other}' -> 'total_number_of_others_is_total_other'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/total_members' -> 'total_members'
# [Regex] 'Family Members Details/Total Number of Family Members and Age Group Details/Total Number of family members is ${total_members}' -> 'total_number_of_family_members_is_total_members'
# [Regex] 'Family Members Details/Identity Revealing Document/Do the house members have identity revealing documents? (के तपाइँ र तपाईको घरका सदस्यहरुसंग आफ्नो परिचय खुल्ने कागजात छ?)' -> 'do_the_house_members_have_identity_revealing_documents'
# [Regex] 'Family Members Details/Identity Revealing Document/If few members do not have, specify the number. (यदि कसैको छैन भने, कति जनाको छैन यहाँ उल्लेख गर्नुहोस)' -> 'if_few_members_do_numbert_have_specify_the_number'
# [Regex] 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Pregnant and Lactating (गर्भवती तथा स्तनपान गराउने)' -> 'pregnant_and_lactating'
# [Regex] 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Widowed (विदुवा/विदुर)' -> ''
# [Regex] 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Chronically ill (दिर्घकालिन रोग भएको)' -> 'chronically_ill'
# [Regex] 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)' -> 'people_with_disability'
# [Regex] 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/Single Woman (एकल महिला)' -> 'single_woman'
# [Regex] 'Family Members Details/Sensitive Population in the house/Do any of your family member fall under following sensitive population? (के तपाईको घरका सदस्य निम्न लिखित सवेदनशील जनसंख्यामा पर्नुहुन्छ?)/None of the above (माथिका कुनै पनि छैन)' -> 'numberne_of_the_above'
# [Regex] 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, specify the number. (यदि गर्भवती र स्तनपान गराउने हुनुहुन्छ भने, कति जना हुनुहुन्छ?' -> 'if_pregnant_and_lactating_specify_the_number'
# [Regex] 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If pregnant and lactating, are they differently abled? (यदि गर्भवती तथा स्तनपान गराउने भए, उहाहरु अपाङ्गता भएको वा फरक रुपमा सक्षम हुनुहुन्छ?)' -> 'if_pregnant_and_lactating_are_they_differently_abled'
# [Regex] 'Family Members Details/Sensitive Population in the house/Pregnant and Lactating/If yes, please write down the number of people with disability pregnant and lactating woman (यदि हुनुन्छ भने, अपाङ्गता भएको वा फरक रुपमा सक्षम कति जना हुनुन्छ?' -> 'if_yes_please_write_down_the_number_of_people_with_disability_pregnant_and_lactating_woman'
# [Regex] 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Female (महिला)' -> 'female'
# [Regex] 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Male (पुरुष)' -> 'male'
# [Regex] 'Family Members Details/Sensitive Population in the house/Widowed/If widowed, specify the gender of widowed members (यदि विदुवा/विदुर हुनुन्छ भने, उहाँहरु तल मध्ये कुन हो?)/Other (अन्य)' -> 'other'
# [Regex] 'Family Members Details/Sensitive Population in the house/Widowed/How many members in the family members are widowed? (घरका कतिजना सदस्य विधवा/विदुर हुनुहुन्छ?)' -> ''
# [Regex] 'Family Members Details/Sensitive Population in the house/Single woman/If single woman, how many members in the family are single woman? (यदि एकल महिला भएमा, कतिजना सदस्य एकल महिलामा पर्नुहुन्छ?)' -> 'if_single_woman_how_many_members_in_the_family_are_single_woman'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)' -> 'female'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)' -> 'male'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If differently abled, specify the gender of the differently abled family members (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, उहाँहरु तलका मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)' -> 'other'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, how many members in the family are people with disability? (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, घरमा कतिजना फरक रुपमा सक्षम हुनुहुन्छ?)' -> 'if_people_with_disability_how_many_members_in_the_family_are_people_with_disability'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Physical disabilities (शारीरिक असक्षमता)' -> 'physical_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Visual disabilities (दृष्टि असक्षमता)' -> 'visual_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing disabilities (श्रवण असक्षमता)' -> 'hearing_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Hearing-Visual disabilities (श्रवण-दृश्य असक्षमता)' -> 'hearing_visual_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Speaking disabilities (बोल्ने असक्षमता)' -> 'speaking_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Mental disabilities (मानसिक असक्षमता)' -> 'mental_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Intellectual disabilities (बौद्दिक  असक्षमता)' -> 'intellectual_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/If people with disability, specify the type of disability (यदि शारिरिक तथा मानसिक अपांगता हुनुहुन्छ भने, यी मध्ये कुनमा पर्नुहुन्छ?)/Multiple disabilities (धेरै असक्षमताहरु)' -> 'multiple_disabilities'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/Do the people with disability family member have identity revealing document provided by municipality? (के शारिरिक तथा मानसिक अपांगता भएको परिचय पत्र पालिका बाट प्राप्त गर्नुभएको छ?)' -> 'do_the_people_with_disability_family_member_have_identity_revealing_document_provided_by_municipality'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Red Card (रातो कार्ड)' -> 'red_card'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Blue Card (निलो कार्ड)' -> 'blue_card'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/Yellow Card (पहेलो कार्ड)' -> 'yellow_card'
# [Regex] 'Family Members Details/Sensitive Population in the house/Differently Abled/Which type of card have the people with disability member taken? (शारिरिक तथा मानसिक अपांगता व्यक्तिले कुन रंगको कार्ड प्राप्त गर्नुभएको छ?)/White Card (सेतो कार्ड)' -> 'white_card'
# [Regex] 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Female (महिला)' -> 'female'
# [Regex] 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Male (पुरुष)' -> 'male'
# [Regex] 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, specify gender of chronically ill family members (यदि दिर्घकालिन रोग भएमा, यी मध्ये कुनमा पर्नुहुन्छ?)/Other (अन्य)' -> 'other'
# [Regex] 'Family Members Details/Sensitive Population in the house/Chronically ill/If chronically ill, how many members in the family are chronically ill? (यदि दिर्घकालिन रोग भएमा, घरका कतिजना सदस्यहरुलाइ दिर्घकालिन रोग छ?)' -> 'if_chronically_ill_how_many_members_in_the_family_are_chronically_ill'
# [Regex] 'Family Members Details/Education Status/Literacy/Total literate female members in the house ( घरमा कुल साक्षर महिला सदस्यहरू)' -> 'total_literate_female_members_in_the_house'
# [Regex] 'Family Members Details/Education Status/Literacy/Total literate male members in the house ( घरमा कुल साक्षर पुरुष सदस्यहरू)' -> 'total_literate_male_members_in_the_house'
# [Regex] 'Family Members Details/Education Status/Literacy/Total literate other gender members in the house ( घरमा कुल साक्षर महिला वा पुरुष भनि पहिचान नगर्ने  सदस्यहरू)' -> 'total_literate_other_gender_members_in_the_house'
# [Regex] 'Family Members Details/Education Status/Literacy/total_literate' -> 'total_literate'
# [Regex] 'Family Members Details/Education Status/Literacy/Total literate members of age between (15-60) years in the house (घरमा (१५-६०) वर्ष उमेर समुहका कुल साक्षर सदस्यहरू)' -> 'total_literate_members_of_age_between_15_60_years_in_the_house'
# [Regex] 'Family Members Details/Education Status/Total Number of Literate Family Members is ${total_literate}' -> 'total_number_of_literate_family_members_is_total_literate'
# [Regex] 'Family Members Details/Education Status/total_illiterate' -> 'total_illiterate'
# [Regex] 'Family Members Details/Education Status/Total Number of Illiterate Family Members is ${total_illiterate}' -> 'total_number_of_illiterate_family_members_is_total_illiterate'
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members who are not eligible for schooling  (परिवारका कुल सदस्यहरू जो पढ्न योग्य नभएका)' -> 'total_family_members_who_are_numbert_eligible_for_schooling'
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members with other/non-formal education (अन्य/अनौपचारिक शिक्षा लिएका परिवारका कुल सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members whose education level is not known ( कुल परिवारका सदस्य जसको शिक्षा स्तर थाहा छैन)' -> 'total_family_members_whose_education_level_is_numbert_knumberwn'
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at primary level of schooling (कक्षा ५ सम्म) विद्यालयको प्राथमिक तहमा (पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at Lower Secondary level of schooling (विद्यालयको निम्न माध्यमिक तहमा  (कक्षा ८ सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at Secondary level of schooling (विद्यालयको  माध्यमिक तहमा ((कक्षा ९ वा १० सम्म) पढ्ने/पढेका  कुल परिवारका सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at SLC or Equivalent level of schooling (SLC वा सो सरह स्तरमा पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at Intermediate or Equivalent level of schooling (+२ पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at Bachelor or Equivalent level of schooling (ब्याचलर वा सो सरह पढेका/पढ्ने परिवारका कुल सदस्यहरू)' -> ''
# [Regex] 'Family Members Details/Education Status/Education Level/Total family members at Masters / Ph.D level of education (मास्टर्स/पी.एच.डी पढ्ने/पढेका परिवारका कुल सदस्यहरू)' -> ''
# [Regex] 'Other Family Members Details/Are there any other families living in the same house? (तपाईको घरमा अन्य कुनै परिवार बस्नुहुन्छ?)' -> 'are_there_any_other_families_living_in_the_same_house'
# [Regex] 'Other Family Members Details/If yes, how many female members are there? (यदि बस्नुहुन्छ भने, महिला सदस्य कतिजना हुनुहुन्छ?)' -> 'if_yes_how_many_female_members_are_there'
# [Regex] 'Other Family Members Details/How many male members are there? (यदि बस्नुहुन्छ भने, पुरुष सदस्य कतिजना हुनुहुन्छ?)' -> 'how_many_male_members_are_there'
# [Regex] 'Other Family Members Details/How many members of other gender are there ? (यदि बस्नुहुन्छ भने, अन्य महिला वा पुरुष भनि पहिचान नगर्ने सदस्य कतिजना हुनुहुन्छ?)' -> 'how_many_members_of_other_gender_are_there'
# [Regex] 'Economic Condition of the House Owner Family/Major Occupation/What is the primary occupation of your family? (तपाईको घरको प्रमुख पेशा कुन हो?)' -> 'what_is_the_primary_occupation_of_your_family'
# [Regex] 'Economic Condition of the House Owner Family/Major Occupation/If other, please specify (यदि अन्य मुख्य पेशा भए, यहाँ उल्लेख गर्नुहोस्)' -> 'if_other_please_specify'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Agriculture and Livestock (कृषि तथा पशुपालन)' -> 'agriculture_and_livestock'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/On-farm Daily Wage Worker (कृषि क्षेत्रमा दैनिक ज्याला मजदुर)' -> 'on_farm_daily_wage_worker'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Off-farm Daily Wage Worker (गैर कृषि क्षेत्रमा दैनिक ज्याला मजदुर)' -> 'off_farm_daily_wage_worker'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Business (व्यापार तथा व्यवसाय)' -> 'business'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Government Service (सरकारी सेवा)' -> 'government_service'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Private Job (निजी सेवा)' -> 'private_job'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Foreign Employment/Remittance (वैदेशिक रोजगार)' -> 'remittance'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/Other (अन्य)' -> 'other'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/What is the secondary Occupation of your family? (तपाइको घरको सहायक पेशा के हो?)/No supporting occupation (कुनै सहायक पेशा छैन)' -> 'number_supporting_occupation'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/If other, please specify (यदि अन्य सहायक पेशा भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_please_specify'
# [Regex] 'Economic Condition of the House Owner Family/Supporting Occupation/Number of unemployed members in the household (घरमा कतिजना वेरोजगार हुनुहुन्छ?)' -> 'number_of_unemployed_members_in_the_household'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Do you or your family members own land? (के तपाइँ र तपाइको परिवारको नाममा जग्गा-जमिन छ?)' -> 'do_you_or_your_family_members_own_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/How much land do you or your family hold? (तपाइँ र तपाईको परिवारको जग्गा कति छ?)' -> 'how_much_land_do_you_or_your_family_hold'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)' -> 'please_choose_the_unit_of_measurement_of_land_area'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other type, please specify the type of land (यदि अन्य भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_please_specify_the_type_of_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)' -> ''
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)' -> ''
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Forested Area (वन क्षेत्र)' -> 'forested_area'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Open Space (खुल्ला स्थान)' -> 'open_space'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Commercial Purpose (व्यापारिक क्षेत्र)' -> 'commercial_purpose'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)' -> 'barren_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/Land Use Type (भू-उपयोगको स्तिथि)/Other (अन्य)' -> 'other'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land holding details of the family members/If other land type, please specify the type of land (यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_land_type_please_specify_the_type_of_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Do the female members of the house own the land? (घरको महिला सदस्यको नाममा जग्गा-जमिन छ?)' -> 'do_the_female_members_of_the_house_own_the_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Total land held by female of the house (घरको महिला सदस्यको नाममा भएको जग्गा कति छ?)' -> 'total_land_held_by_female_of_the_house'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Please choose the unit of measurement of land area. (कृपया जमिनको क्षेत्रफल नाप्ने इकाइ छनोट गर्नुहोस्)' -> 'please_choose_the_unit_of_measurement_of_land_area'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type that helds by female, please specify the type of land (महिला सदस्यले यदि अन्य प्रयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_land_type_that_helds_by_female_please_specify_the_type_of_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Built-up Area/Land (संरचना भएको क्षेत्र/जमिन)' -> ''
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Cultivation Area/Land (खेति गरेको क्षेत्र/जमिन)' -> ''
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Forested Area (वन क्षेत्र)' -> 'forested_area'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Open Space (खुल्ला स्थान)' -> 'open_space'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Commercial Purpose (व्यापारिक क्षेत्र)' -> 'commercial_purpose'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Unused/Barren Land (प्रयोग नभएको अथवा बाँझो जमिन)' -> 'barren_land'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/Type of land holding by female (घरको महिला सदस्यको नाममा भएको जग्गा तलउल्लेख मध्ये कुन-कुन मा पर्दछ?)/Other (अन्य)' -> 'other'
# [Regex] 'Economic Condition of the House Owner Family/Land Holding/Land Holding by female members/If other land type, specify here. (यदि अन्य भू-उपयोग भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_land_type_specify_here'
# [Regex] 'Economic Condition of the House Owner Family/Income and Expenditure/Annual income of the family (वार्षिक आम्दानी)' -> 'annual_income_of_the_family'
# [Regex] 'Economic Condition of the House Owner Family/Income and Expenditure/Monthly Expenditure of the house  (घरको मासिक खर्च)' -> 'monthly_expenditure_of_the_house'
# [Regex] 'Economic Condition of the House Owner Family/Income and Expenditure/Yearly saving of the house  (घरको वार्षिक बचत)' -> 'yearly_saving_of_the_house'
# [Regex] 'Economic Condition of the House Owner Family/Saving, Credit and Loan/Have you taken loan from the financial institutions? (के तपाइले कुनै वित्तीय संस्था बाट ऋण लिनुभएको छ?)' -> 'have_you_taken_loan_from_the_financial_institutions'
# [Regex] 'Economic Condition of the House Owner Family/Saving, Credit and Loan/Covered by subsidized loan targeted for women/marginalized group (घरको  महिला/सीमान्तकृत समूहका लागि लक्षित सहुलियतपूर्ण ऋण पाएको छ?)' -> ''
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Is any family member receiving reservations, allowances and special privilege systems? (के तपाइको घरको कुनै सदस्यले कुनै आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)' -> 'is_any_family_member_receiving_reservations_allowances_and_special_privilege_systems'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen (ज्येष्ठ नागरिक)' -> 'senior_citizen'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Dalit (ज्येष्ठ नागरिक दलित)' -> 'senior_citizen_dalit'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Senior Citizen Single Women (ज्येष्ठ नागरिक एकल महिला)' -> 'senior_citizen_single_women'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Widowed (विधवा/ एकल महिला)' -> ''
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/People with Disability (शारिरिक तथा मानसिक अपांगता भएको)' -> 'people_with_disability'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Dalit Child Allowance (दलित बाल बालिका)' -> 'dalit_child_allowance'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Pension (पेन्सन)' -> 'pension'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If yes, what type of Reservations, allowances and special privilege systems are being received? (यदि छ भने, निम्न मध्ये कुन आरक्षण, भत्ता तथा विशेष सुविधाहरु पाउनुभएको छ?)/Others (अन्य)' -> 'others'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/If other type of privilege system, please specify (यदि अन्य किसिमको सुविधाहरु भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_type_of_privilege_system_please_specify'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen allowance (वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_allowance'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen dalit allowance (दलित वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_dalit_allowance'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving elderly citizen single woman allowance (महिला वृद्द भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_elderly_citizen_single_woman_allowance'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  widowed allowance (विधवा भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_widowed_allowance'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  allowance for differently abled (अपाङ्गता भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_allowance_for_differently_abled'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving  allowance for dalit child (दलित बाल-बालिका  भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_allowance_for_dalit_child'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving pension (पेन्सन पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_pension'
# [Regex] 'Economic Condition of the House Owner Family/Reservations, Allowances and Special Privilege System/Number of family members receiving other type of allowance (अन्य किसिमका भत्ता पाउनुहुने घरका सदस्य)' -> 'number_of_family_members_receiving_other_type_of_allowance'
# [Regex] 'Economic Condition of the House Owner Family/Insurance Details/Have you or your family member taken any type of insurance? (के तपाइ तथा तपाँईको परिवारको कुनै सदस्यहरूले विमा गर्नुभएको छ?)' -> 'have_you_or_your_family_member_taken_any_type_of_insurance'
# [Regex] 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Life Insurance (जीवन विमा)' -> 'life_insurance'
# [Regex] 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Animal Insurance (पशु विमा)' -> 'animal_insurance'
# [Regex] 'Economic Condition of the House Owner Family/Insurance Details/If yes, what type of insurance have you or your family members taken? (यदि छ भने, तथा तपाँईको परिवारको कुनै सदस्यहरूले निम्न उल्लेख मध्ये कुन कुन विमा गर्नुभएको छ?)/Crop Insurance (बाली विमा)' -> 'crop_insurance'
# ...
# [Regex] 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Raised Plinth and above flood level (उठाएको प्लिन्थ-बाढीको सतह भन्दा माथि)' -> 'raised_plinth_and_above_flood_level'
# [Regex] 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Strong wall (मजबुत पर्खाल)' -> 'strong_wall'
# [Regex] 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/Proper drainage (उचित ढल/जल निकासी)' -> ''
# [Regex] 'Details on the House/Current Condition/Does your house have the following features? (तपाइको घरमा तल उल्लेख मध्ये कुनै संरचना निर्माण गरिएको छ?)/None of the above (माथिको कुनै पनि होइन)' -> 'numberne_of_the_above'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years, how many times have you experienced flooding events? (विगत ३० वर्षमा तपाइले कति पटक बाढीका घटनाहरुको अनुभव गर्नुभएको छ?)' -> 'in_the_past_30_years_how_many_times_have_you_experienced_flooding_events'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past flooding events, what is the maximum depth of flood occurrence surrounding the household? विगतको बाढी घटनामा, घर वरिपरि बाढीको अधिकतम गहिराई कति थियो ?' -> 'in_the_past_flooding_events_what_is_the_maximum_depth_of_flood_occurrence_surrounding_the_household'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Select the unit of flood depth measurement. (बाढीको गहिराई नाप्ने इकाइ चयन गर्नुहोस्।)' -> 'select_the_unit_of_flood_depth_measurement'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Death of  household members (परिवारको सदस्यको मृत्यु भएको)' -> 'death_of_household_members'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Missing household members (परिवारको सदस्य हराएको)' -> 'missing_household_members'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Injured household members (परिवारको सदस्य घाइते हुनुभएको)' -> 'injured_household_members'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/People displaced (विस्थापित)' -> 'people_displaced'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to house (घरमा क्षति भएको)' -> 'damage_to_house'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Land affected (जमिन क्षति भएको)' -> 'land_affected'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Livestock affected (पशु क्षति भएको)' -> 'livestock_affected'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Farmland affected (खेति जमिनमा क्षति)' -> 'farmland_affected'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Damage to stored food stock (भण्डारण गरिएको खाद्यान्न क्षति)' -> 'damage_to_stored_food_stock'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Non-Structural Damage (गैर-संरचनात्मक क्षति)' -> 'numbern_structural_damage'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/Loss of other livelihood options ( such as loss of job, business, other than agriculture)' -> 'loss_of_other_livelihood_options_such_as_loss_of_job_business_other_than_agriculture'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/In the past 30 years what damages were caused by the flooding events occurred ? (विगत ३० वर्षमा अनुभव गर्नुभएको बाढीका घटनाहरुमा केहि क्षति भएको थियो?)/No any damage (कुनै पनि क्षति नभएको)' -> 'number_any_damage'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Number of people death (मृत्यु हुनेको संख्या)' -> 'number_of_people_death'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Number of missing family members (हराएका परिवारको सदस्यको संख्या)' -> 'number_of_missing_family_members'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Number of injured family members (घाइतेको संख्या)' -> 'number_of_injured_family_members'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Number of people displaced (विस्थापित संख्या)' -> 'number_of_people_displaced'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Total area of farmland affected (कुल खेति जमिन क्षति)' -> 'total_area_of_farmland_affected'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Unit of measurement of affected farmland area (प्रभावित खेति जमिन क्षेत्रको मापनको इकाइ)' -> 'unit_of_measurement_of_affected_farmland_area'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Estimated agricultural loss (कुल कृषि क्षति)' -> 'estimated_agricultural_loss'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Type of damage to the house (घरको क्षतिको प्रकार)' -> 'type_of_damage_to_the_house'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Total livestock loss (कुल पशु क्षतिको संख्या)' -> 'total_livestock_loss'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Estimated livestock loss NPR (कुल पशु क्षति)' -> 'estimated_livestock_loss_npr'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Total loss of stored food KG (भण्डारण गरिएको खाद्यान्न क्षति)' -> 'total_loss_of_stored_food_kg'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/Total Estimated loss NPR (कुल अनुमानित क्षति)' -> 'total_estimated_loss_npr'
# [Regex] 'Hazard and Disaster/Historical Damage and Loss/If loss of other livelihood options, please specify. अन्य जीविकोपार्जनका विकल्पहरू गुमाएमा, कृपया यहाँ उल्लेख गर्नुहोस्।' -> 'if_loss_of_other_livelihood_options_please_specify'
# [Regex] 'Hazard and Disaster/Knowledge and Training in Disaster/Have any family members received training on disaster? (के तपाइँ वा तपाईको परिवारको सदस्यले विपद सम्बन्धी तालिम लिनुभएको छ?)' -> 'have_any_family_members_received_training_on_disaster'
# [Regex] 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/First Aid (प्राथमिक उपचार)' -> 'first_aid'
# [Regex] 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Search and rescue (खोज तथा उद्दार)' -> 'search_and_rescue'
# [Regex] 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Simulation and drill exercise (सिमुलेशन र ड्रिल)' -> 'simulation_and_drill_exercise'
# [Regex] 'Hazard and Disaster/Knowledge and Training in Disaster/If yes, type of training received (यदि तालिम लिनुभएको छ भने, तल उल्लेख मध्ये कुन-कुन तालिम लिनुभएको छ?)/Other Disaster related training (विपद सम्बन्धी अन्य तालिम)' -> 'other_disaster_related_training'
# [Regex] 'Hazard and Disaster/Knowledge and Training in Disaster/If other disaster related trainings received, please specify what type of trainings. (यदि विपद सम्बन्धी अन्य तालिम भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_disaster_related_trainings_received_please_specify_what_type_of_trainings'
# [Regex] 'Hazard and Disaster/Aftermath of Past Disaster/Access to social assistance in the aftermath of past disaster (विगतको प्रकोप पछि सामाजिक सहायता प्राप्त भएको थियो?)' -> 'access_to_social_assistance_in_the_aftermath_of_past_disaster'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/DRRM committee of ward/municipality (पालिका वा वडाको विपद सम्बन्धी समितिमा)' -> 'municipality'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Women group (महिला समुह)' -> 'women_group'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Youth group (युवा समुह)' -> 'youth_group'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Child group (बाल समुह)' -> 'child_group'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Single women's group (एकल महिला समुह)' -> 'single_women_s_group'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Scout/Red cross (स्काउट/ रेड क्रस)' -> ''
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/Other (अन्य)' -> 'other'
# [Regex] 'Community Groups/Are you or any of your family are a member of any of the following community groups? (के तपाइँ वा परिवारको सदस्य तल उल्लेख मध्ये कुनै समूहको सदस्य हुनुहुन्छ?)/No (कुनैमा पनि छैन)' -> 'number'
# [Regex] 'Community Groups/If other, please specify. (यदि अन्य समुह भएमा, यहाँ उल्लेख गर्नुहोस)' -> 'if_other_please_specify'
# [Regex] 'Community Groups/Women's participation in community/ ward/ municipal meeting and or decision making process (सामुदायिक/वडा/नगरपालिका  बैठक र निर्णय प्रक्रियामा घरको महिलाहरूको सहभागिता)' -> ''
# [Regex] 'Citizenship Number of House Owner (नागरिकता नं)' -> 'citizenship_number_of_house_owner'
# [Regex] 'Phone number (फोन नं)' -> 'phone_number'
# [Regex] 'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)' -> 'please_take_the_picture_of_the_house'
# [Regex] 'Please take the picture of the house (सर्वेक्षण गरेको घरको फोटो खिच्नुहोस)_URL' -> 'please_take_the_picture_of_the_house__url'
# [Regex] 'unique_identity' -> 'unique_identity'
# [Regex] 'Your household unique ID is ${unique_identity}' -> 'your_household_unique_id_is_unique_identity'
# [Regex] '__version__' -> 'version'
# [Regex] '_id' -> 'id'
# [Regex] '_uuid' -> 'uuid'
# [Regex] '_submission_time' -> 'submission_time'
# [Regex] '_validation_status' -> 'validation_status'
# [Regex] '_notes' -> 'numbertes'
# [Regex] '_status' -> 'status'
# [Regex] '_submitted_by' -> 'submitted_by'
# [Regex] '_tags' -> 'tags'
# [Regex] '_index' -> 'index'
# [Regex] 'Unnamed: 341' -> 'unnamed_341'
# [Regex] 'Unnamed: 342' -> 'unnamed_342'
# [Regex] 'Unnamed: 343' -> 'unnamed_343'
# [Regex] 'Unnamed: 344' -> 'unnamed_344'
# [Regex] 'परिवारको जग्गा in KATHA' -> 'in_katha'
# [Regex] 'महिला सदस्यको नाममा भएको जग्गा in KATHA' -> 'in_katha'
# [Regex] 'घरबाट खानेपानी सुविधाको दूरी in METER' -> 'in_meter'
# [Regex] 'घरबाट स्वास्थ्य संस्थाको दुरी in METER' -> 'in_meter'
# [Regex] '(घरबाट बजारको दुरी in METER' -> 'in_meter'
# [Regex] '(नजिकैको शौचालय र घरको दुरी in METER' -> 'in_meter'
# [Regex] '(Distance to safe Shelter in METER)' -> 'distance_to_safe_shelter_in_meter'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2736387861.py in <cell line: 0>()
#       6
#       7     module = HeaderStandardizer(headers)
# ----> 8     regex_map, clean_map = module.run()
#       9     module.save_json("standardized_headers_final5.json")
#
# /tmp/ipython-input-4028221881.py in run(self)
#      20         cleaner = dspy.ChainOfThought(CleanHeaderToLabel)
#      21         for h in self.headers:
# ---> 22             result = cleaner(raw_header=h.strip().strip("'"))
#      23             self.mapping_clean[h] = result.clean_label
#      24             print(f"[DSPy]  '{h}' -> '{result.clean_label}'")
#
# /usr/local/lib/python3.12/dist-packages/dspy/utils/callback.py in sync_wrapper(instance, *args, **kwargs)
#     324             callbacks = _get_active_callbacks(instance)
#     325             if not callbacks:
# --> 326                 return fn(instance, *args, **kwargs)
#     327
#     328             call_id = uuid.uuid4().hex
#
# /usr/local/lib/python3.12/dist-packages/dspy/primitives/module.py in __call__(self, *args, **kwargs)
#      79                 return output
#      80
# ---> 81             return self.forward(*args, **kwargs)
#      82
#      83     @with_callbacks
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/chain_of_thought.py in forward(self, **kwargs)
#      35
#      36     def forward(self, **kwargs):
# ---> 37         return self.predict(**kwargs)
#      38
#      39     async def aforward(self, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/predict.py in __call__(self, *args, **kwargs)
#     101             raise ValueError(self._get_positional_args_error_message())
#     102
# --> 103         return super().__call__(**kwargs)
#     104
#     105     async def acall(self, *args, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/dspy/utils/callback.py in sync_wrapper(instance, *args, **kwargs)
#     324             callbacks = _get_active_callbacks(instance)
#     325             if not callbacks:
# --> 326                 return fn(instance, *args, **kwargs)
#     327
#     328             call_id = uuid.uuid4().hex
#
# /usr/local/lib/python3.12/dist-packages/dspy/primitives/module.py in __call__(self, *args, **kwargs)
#      79                 return output
#      80
# ---> 81             return self.forward(*args, **kwargs)
#      82
#      83     @with_callbacks
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/predict.py in forward(self, **kwargs)
#     181
#     182     def forward(self, **kwargs):
# --> 183         lm, config, signature, demos, kwargs = self._forward_preprocess(**kwargs)
#     184
#     185         adapter = settings.adapter or ChatAdapter()
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/predict.py in _forward_preprocess(self, **kwargs)
#     120
#     121         if lm is None:
# --> 122             raise ValueError(
#     123                 "No LM is loaded. Please configure the LM using `dspy.configure(lm=dspy.LM(...))`. e.g, "
#     124                 "`dspy.configure(lm=dspy.LM('openai/gpt-4o-mini'))`"
#
# ValueError: No LM is loaded. Please configure the LM using `dspy.configure(lm=dspy.LM(...))`. e.g, `dspy.configure(lm=dspy.LM('openai/gpt-4o-mini'))`
